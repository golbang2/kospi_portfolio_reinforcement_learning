# %%
import tensorflow as tf
import matplotlib.pyplot as plt
from collections import deque
import network
import environment
import numpy as np
# Out:
# WARNING:tensorflow:
# The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
#   * https://github.com/tensorflow/io (for I/O related ops)
# If you depend on functionality not listed there, please file an issue.

# %%
def memory_queue(memory,weight):
    weight = np.expand_dims(weight.T,axis=1)
    memory = np.concatenate((weight,memory),axis=2)[:,:,:-1]
    return memory

def MM_scaler(s):
    x= np.zeros(s.shape)
    for i in range(len(s)):
        x[i]=(s[i]-np.min(s[i],axis=0))/((np.max(s[i],axis=0)-np.min(s[i],axis=0))+1e-5)
    return x

# %%
#preprocessed data loading
is_train = 1

#hyperparameters
memory_size = 20
input_day_size = 50
filter_size = 3
num_of_feature = 4
num_of_asset = 10
num_episodes = 5000 if is_train ==1 else 1
money = 1e+8

#saving
save_frequency = 100
save_path = './algorithms'
save_model = 1
load_model = 0
selecting_random = True
if is_train==0:
    env = environment.env(train = 0)
    load_model = 1
    selecting_random = False
else:
    env = environment.env()

config = tf.ConfigProto(allow_soft_placement=True, log_device_placement=True)
config.gpu_options.allow_growth = True

a_loss_sum = 0
s_loss_sum = 0

# %%
with tf.Session(config=config) as sess:
    allocator=network.policy(sess)
    selector = network.select_network(sess)
    sess.run(tf.global_variables_initializer())
    
    if save_model:
        saver = tf.train.Saver(max_to_keep=100)
        ckpt = tf.train.get_checkpoint_state(save_path)
        if load_model:
            saver.restore(sess,ckpt.model_checkpoint_path)
    score = 0
    vench = 0
    value_list = []
    for i in range(num_episodes):
        allocator_memory = deque()
        selector_memory = deque()
        s=env.start()
        s=MM_scaler(s)
        done=False
        v=money
        weight_memory = []
        while not done:
            evaluated_value = selector.predict(s)
            selected_s = env.selecting(evaluated_value,rand=selecting_random)
            selected_s = MM_scaler(selected_s)
            w = allocator.predict(selected_s)
            s_prime,r,done,v_prime,growth = env.action(w)
            s_prime=MM_scaler(s_prime)
            allocator_memory.append([selected_s,r])
            selector_memory.append([s,growth])
            weight_memory.append(w)
            s = s_prime
            v = v_prime
            value_list.append(v)
            if done:
                score+=v/money
                if is_train ==1:
                    s_loss = selector.update(selector_memory)
                    a_loss = allocator.update(allocator_memory)
                    print(i,'agent:',round(v/money,4), 'venchmark:',round(env.venchmark/money,4), 'acc: ',round((env.acc[0,0]+env.acc[1,2])/(np.sum(env.acc)-np.sum(env.acc[:,1])),4))
                    s_loss_sum += s_loss
                    a_loss_sum += a_loss
                else:
                    print(i,'agent:',round(v/money,4), 'acc: ',round((env.acc[0,0]+env.acc[1,2])/(np.sum(env.acc)-np.sum(env.acc[:,1])),4))
                
        if save_model == 1 and i % save_frequency == save_frequency - 1:
            saver.save(sess,save_path+'/model-'+str(i)+'.cptk')
            print('saved')
            print('average return: ',(round(score/save_frequency,4)-1)*100,'%')
            print('AAM loss:', a_loss_sum, 'ESM loss:', s_loss_sum)
            score = 0
            vench = 0
            a_loss_sum = 0
            s_loss_sum = 0
# Out:
# Device mapping:
# /job:localhost/replica:0/task:0/device:XLA_CPU:0 -> device: XLA_CPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:0 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:1 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:2 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:3 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:4 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:5 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:6 -> device: XLA_GPU device
# /job:localhost/replica:0/task:0/device:XLA_GPU:7 -> device: XLA_GPU device
#
# INFO:tensorflow:Scale of 0 disables regularizer.
# WARNING:tensorflow:From /home/GB/workspace/kospi_portfolio_reinforcement_learningv4/network.py:23: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1057: Layer.apply (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.__call__` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/contrib/layers/python/layers/layers.py:1634: flatten (from tensorflow.python.layers.core) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use keras.layers.flatten instead.
# WARNING:tensorflow:From /home/GB/workspace/kospi_portfolio_reinforcement_learningv4/network.py:35: The name tf.train.GradientDescentOptimizer is deprecated. Please use tf.compat.v1.train.GradientDescentOptimizer instead.
#
# WARNING:tensorflow:From /home/GB/workspace/kospi_portfolio_reinforcement_learningv4/network.py:58: BasicLSTMCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.LSTMCell, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:From /home/GB/workspace/kospi_portfolio_reinforcement_learningv4/network.py:59: MultiRNNCell.__init__ (from tensorflow.python.ops.rnn_cell_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This class is equivalent as tf.keras.layers.StackedRNNCells, and will be replaced by that in Tensorflow 2.0.
# WARNING:tensorflow:At least two cells provided to MultiRNNCell are the same object and will share weights.
# WARNING:tensorflow:From /home/GB/workspace/kospi_portfolio_reinforcement_learningv4/network.py:60: dynamic_rnn (from tensorflow.python.ops.rnn) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `keras.layers.RNN(cell)`, which is equivalent to this API
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:735: Layer.add_variable (from tensorflow.python.keras.engine.base_layer) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `layer.add_weight` method instead.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow_core/python/ops/rnn_cell_impl.py:739: calling Zeros.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# INFO:tensorflow:Restoring parameters from ./algorithms/model-299.cptk
# 300 agent: 0.811 venchmark: 0.8199 acc:  0.5011
# 301 agent: 0.7595 venchmark: 0.7709 acc:  0.501
# 302 agent: 1.0978 venchmark: 1.1112 acc:  0.501
# 303 agent: 1.2632 venchmark: 1.249 acc:  0.5011
# 304 agent: 0.7224 venchmark: 0.7232 acc:  0.5012
# 305 agent: 1.2411 venchmark: 1.2088 acc:  0.5012
# 306 agent: 1.5478 venchmark: 1.6088 acc:  0.5012
# 307 agent: 1.2902 venchmark: 1.3341 acc:  0.5012
# 308 agent: 0.7656 venchmark: 0.7815 acc:  0.5012
# 309 agent: 1.1192 venchmark: 1.1208 acc:  0.5012
# 310 agent: 1.0586 venchmark: 1.073 acc:  0.5011
# 311 agent: 1.1273 venchmark: 1.1225 acc:  0.5011
# 312 agent: 0.8454 venchmark: 0.8587 acc:  0.5011
# 313 agent: 1.2964 venchmark: 1.2952 acc:  0.5011
# 314 agent: 0.8749 venchmark: 0.8739 acc:  0.5011
# 315 agent: 0.994 venchmark: 0.9818 acc:  0.5011
# 316 agent: 1.0281 venchmark: 1.0347 acc:  0.5012
# 317 agent: 0.7827 venchmark: 0.7884 acc:  0.5012
# 318 agent: 1.0438 venchmark: 1.0422 acc:  0.5011
# 319 agent: 1.1724 venchmark: 1.1549 acc:  0.5011
# 320 agent: 1.3782 venchmark: 1.3872 acc:  0.5011
# 321 agent: 0.8494 venchmark: 0.846 acc:  0.5011
# 322 agent: 1.0629 venchmark: 1.0495 acc:  0.5012
# 323 agent: 0.78 venchmark: 0.7725 acc:  0.5012
# 324 agent: 1.1368 venchmark: 1.1304 acc:  0.5011
# 325 agent: 1.3626 venchmark: 1.3634 acc:  0.5011
# 326 agent: 1.0078 venchmark: 1.0108 acc:  0.5011
# 327 agent: 1.1021 venchmark: 1.1031 acc:  0.5011
# 328 agent: 1.0313 venchmark: 1.0274 acc:  0.5011
# 329 agent: 0.6004 venchmark: 0.6082 acc:  0.5011
# 330 agent: 1.2996 venchmark: 1.2683 acc:  0.5011
# 331 agent: 0.815 venchmark: 0.8329 acc:  0.5011
# 332 agent: 1.0571 venchmark: 1.0483 acc:  0.5011
# 333 agent: 1.4165 venchmark: 1.4161 acc:  0.5012
# 334 agent: 1.1291 venchmark: 1.1366 acc:  0.5012
# 335 agent: 0.8569 venchmark: 0.8771 acc:  0.5013
# 336 agent: 0.9429 venchmark: 0.9326 acc:  0.5013
# 337 agent: 0.9874 venchmark: 0.9852 acc:  0.5013
# 338 agent: 1.0522 venchmark: 1.0511 acc:  0.5012
# 339 agent: 0.9946 venchmark: 1.0116 acc:  0.5012
# 340 agent: 1.6422 venchmark: 1.6301 acc:  0.5012
# 341 agent: 0.7925 venchmark: 0.7848 acc:  0.5011
# 342 agent: 0.9702 venchmark: 0.9588 acc:  0.5011
# 343 agent: 1.512 venchmark: 1.4834 acc:  0.5012
# 344 agent: 0.8467 venchmark: 0.8559 acc:  0.5012
# 345 agent: 1.2097 venchmark: 1.2101 acc:  0.5012
# 346 agent: 1.167 venchmark: 1.1307 acc:  0.5011
# 347 agent: 1.0454 venchmark: 1.0499 acc:  0.5011
# 348 agent: 1.2944 venchmark: 1.325 acc:  0.5012
# 349 agent: 1.2569 venchmark: 1.2818 acc:  0.5012
# 350 agent: 1.0833 venchmark: 1.0755 acc:  0.5012
# 351 agent: 0.9583 venchmark: 0.9234 acc:  0.5013
# 352 agent: 0.8919 venchmark: 0.8996 acc:  0.5013
# 353 agent: 0.9357 venchmark: 0.9494 acc:  0.5012
# 354 agent: 1.1345 venchmark: 1.1368 acc:  0.5013
# 355 agent: 1.4702 venchmark: 1.4973 acc:  0.5013
# 356 agent: 1.2131 venchmark: 1.2453 acc:  0.5013
# 357 agent: 1.0065 venchmark: 1.0134 acc:  0.5014
# 358 agent: 0.857 venchmark: 0.8645 acc:  0.5013
# 359 agent: 1.163 venchmark: 1.1526 acc:  0.5014
# 360 agent: 0.7812 venchmark: 0.7715 acc:  0.5014
# 361 agent: 0.8345 venchmark: 0.8402 acc:  0.5013
# 362 agent: 1.0284 venchmark: 1.0398 acc:  0.5013
# 363 agent: 0.8973 venchmark: 0.9023 acc:  0.5013
# 364 agent: 1.1838 venchmark: 1.1832 acc:  0.5014
# 365 agent: 1.6626 venchmark: 1.6755 acc:  0.5014
# 366 agent: 1.7175 venchmark: 1.7323 acc:  0.5014
# 367 agent: 0.8603 venchmark: 0.8559 acc:  0.5015
# 368 agent: 1.0023 venchmark: 1.0107 acc:  0.5014
# 369 agent: 0.8608 venchmark: 0.8612 acc:  0.5015
# 370 agent: 1.0293 venchmark: 1.0271 acc:  0.5015
# 371 agent: 1.4137 venchmark: 1.4138 acc:  0.5015
# 372 agent: 1.4032 venchmark: 1.4061 acc:  0.5015
# 373 agent: 1.1902 venchmark: 1.2193 acc:  0.5015
# 374 agent: 0.9242 venchmark: 0.9407 acc:  0.5015
# 375 agent: 1.3379 venchmark: 1.365 acc:  0.5016
# 376 agent: 0.9494 venchmark: 0.9533 acc:  0.5016
# 377 agent: 0.8574 venchmark: 0.8875 acc:  0.5016
# 378 agent: 1.066 venchmark: 1.0811 acc:  0.5017
# 379 agent: 0.9275 venchmark: 0.9422 acc:  0.5016
# 380 agent: 1.0939 venchmark: 1.0978 acc:  0.5016
# 381 agent: 1.6731 venchmark: 1.6544 acc:  0.5016
# 382 agent: 0.9525 venchmark: 0.9524 acc:  0.5016
# 383 agent: 1.0486 venchmark: 1.0469 acc:  0.5017
# 384 agent: 0.8316 venchmark: 0.8231 acc:  0.5016
# 385 agent: 1.0544 venchmark: 1.0586 acc:  0.5016
# 386 agent: 1.5592 venchmark: 1.5431 acc:  0.5016
# 387 agent: 1.2333 venchmark: 1.2328 acc:  0.5016
# 388 agent: 1.4189 venchmark: 1.3909 acc:  0.5015
# 389 agent: 1.1108 venchmark: 1.1236 acc:  0.5016
# 390 agent: 0.9092 venchmark: 0.911 acc:  0.5016
# 391 agent: 0.9567 venchmark: 0.9422 acc:  0.5016
# 392 agent: 1.0841 venchmark: 1.0813 acc:  0.5017
# 393 agent: 1.0634 venchmark: 1.075 acc:  0.5018
# 394 agent: 1.3812 venchmark: 1.3875 acc:  0.5017
# 395 agent: 1.1005 venchmark: 1.0832 acc:  0.5017
# 396 agent: 1.4884 venchmark: 1.4672 acc:  0.5017
# 397 agent: 1.1715 venchmark: 1.138 acc:  0.5017
# 398 agent: 1.0428 venchmark: 1.0441 acc:  0.5017
# 399 agent: 1.1027 venchmark: 1.1115 acc:  0.5017
# saved
# average return:  9.35999999999999 %
# AAM loss: 18.367856711149216 ESM loss: 1977683.5165110826
# 400 agent: 0.7602 venchmark: 0.7594 acc:  0.5016
# 401 agent: 1.0983 venchmark: 1.1006 acc:  0.5017
# 402 agent: 0.986 venchmark: 0.9955 acc:  0.5017
# 403 agent: 0.9107 venchmark: 0.8888 acc:  0.5017
# 404 agent: 0.7908 venchmark: 0.7786 acc:  0.5017
# 405 agent: 0.854 venchmark: 0.8657 acc:  0.5018
# 406 agent: 1.0439 venchmark: 1.0582 acc:  0.5018
# 407 agent: 0.7831 venchmark: 0.7955 acc:  0.5018
# 408 agent: 1.3586 venchmark: 1.3314 acc:  0.5018
# 409 agent: 1.0474 venchmark: 1.04 acc:  0.5018
# 410 agent: 1.073 venchmark: 1.0905 acc:  0.5018
# 411 agent: 0.9653 venchmark: 0.9255 acc:  0.5019
# 412 agent: 0.9569 venchmark: 0.9487 acc:  0.5019
# 413 agent: 1.5828 venchmark: 1.5815 acc:  0.5019
# 414 agent: 0.9956 venchmark: 0.9517 acc:  0.5019
# 415 agent: 0.9962 venchmark: 1.0295 acc:  0.5019
# 416 agent: 1.3157 venchmark: 1.2619 acc:  0.5019
# 417 agent: 1.2107 venchmark: 1.2185 acc:  0.5019
# 418 agent: 1.1028 venchmark: 1.1094 acc:  0.5018
# 419 agent: 1.0966 venchmark: 1.0629 acc:  0.5018
# 420 agent: 0.9033 venchmark: 0.8935 acc:  0.5017
# 421 agent: 0.8366 venchmark: 0.8274 acc:  0.5017
# 422 agent: 1.1053 venchmark: 1.0977 acc:  0.5018
# 423 agent: 0.8798 venchmark: 0.8868 acc:  0.5017
# 424 agent: 1.071 venchmark: 1.0653 acc:  0.5018
# 425 agent: 0.849 venchmark: 0.8913 acc:  0.5018
# 426 agent: 0.9362 venchmark: 0.9589 acc:  0.5018
# 427 agent: 1.1822 venchmark: 1.1802 acc:  0.5018
# 428 agent: 0.9737 venchmark: 0.983 acc:  0.5018
# 429 agent: 0.7943 venchmark: 0.7713 acc:  0.5017
# 430 agent: 1.0606 venchmark: 1.0368 acc:  0.5017
# 431 agent: 0.9201 venchmark: 0.9453 acc:  0.5017
# 432 agent: 0.9557 venchmark: 0.9604 acc:  0.5017
# 433 agent: 1.1115 venchmark: 1.1262 acc:  0.5018
# 434 agent: 1.0623 venchmark: 1.1118 acc:  0.5017
# 435 agent: 0.9109 venchmark: 0.9054 acc:  0.5017
# 436 agent: 1.0645 venchmark: 1.0684 acc:  0.5017
# 437 agent: 0.9652 venchmark: 0.9764 acc:  0.5017
# 438 agent: 1.0958 venchmark: 1.1042 acc:  0.5017
# 439 agent: 0.9084 venchmark: 0.9075 acc:  0.5017
# 440 agent: 0.7182 venchmark: 0.6995 acc:  0.5017
# 441 agent: 1.2927 venchmark: 1.2846 acc:  0.5017
# 442 agent: 1.0843 venchmark: 1.0514 acc:  0.5018
# 443 agent: 1.0748 venchmark: 1.0936 acc:  0.5019
# 444 agent: 0.9582 venchmark: 0.939 acc:  0.5018
# 445 agent: 1.0231 venchmark: 1.0174 acc:  0.5018
# 446 agent: 1.1213 venchmark: 1.1562 acc:  0.5018
# 447 agent: 0.8586 venchmark: 0.8406 acc:  0.5018
# 448 agent: 0.9727 venchmark: 0.9714 acc:  0.5018
# 449 agent: 1.0009 venchmark: 1.0241 acc:  0.5018
# 450 agent: 1.0823 venchmark: 1.0826 acc:  0.5018
# 451 agent: 1.0131 venchmark: 1.0012 acc:  0.5019
# 452 agent: 1.239 venchmark: 1.2373 acc:  0.5019
# 453 agent: 1.2924 venchmark: 1.2941 acc:  0.502
# 454 agent: 1.1597 venchmark: 1.1981 acc:  0.5019
# 455 agent: 1.3812 venchmark: 1.4206 acc:  0.5019
# 456 agent: 0.8905 venchmark: 0.8983 acc:  0.5019
# 457 agent: 0.8881 venchmark: 0.9112 acc:  0.5019
# 458 agent: 1.1896 venchmark: 1.1926 acc:  0.5019
# 459 agent: 0.8661 venchmark: 0.8387 acc:  0.5018
# 460 agent: 1.107 venchmark: 1.0956 acc:  0.5018
# 461 agent: 0.9429 venchmark: 0.954 acc:  0.5019
# 462 agent: 1.1935 venchmark: 1.1703 acc:  0.5019
# 463 agent: 1.3082 venchmark: 1.3349 acc:  0.5018
# 464 agent: 1.1827 venchmark: 1.1508 acc:  0.5019
# 465 agent: 0.6641 venchmark: 0.6656 acc:  0.502
# 466 agent: 1.0675 venchmark: 1.0536 acc:  0.5019
# 467 agent: 1.0302 venchmark: 1.0181 acc:  0.502
# 468 agent: 1.3682 venchmark: 1.3703 acc:  0.5019
# 469 agent: 0.9591 venchmark: 0.9918 acc:  0.502
# 470 agent: 0.9261 venchmark: 0.9291 acc:  0.502
# 471 agent: 1.138 venchmark: 1.1375 acc:  0.5021
# 472 agent: 1.1939 venchmark: 1.1851 acc:  0.5021
# 473 agent: 0.9214 venchmark: 0.9218 acc:  0.5021
# 474 agent: 1.3847 venchmark: 1.3697 acc:  0.5022
# 475 agent: 0.6861 venchmark: 0.6879 acc:  0.5021
# 476 agent: 1.309 venchmark: 1.3073 acc:  0.5022
# 477 agent: 1.0104 venchmark: 1.0141 acc:  0.5022
# 478 agent: 1.147 venchmark: 1.1597 acc:  0.5021
# 479 agent: 1.3145 venchmark: 1.3258 acc:  0.5022
# 480 agent: 0.8315 venchmark: 0.826 acc:  0.5021
# 481 agent: 1.3194 venchmark: 1.3069 acc:  0.5021
# 482 agent: 1.0466 venchmark: 1.0319 acc:  0.5021
# 483 agent: 0.8444 venchmark: 0.8483 acc:  0.502
# 484 agent: 1.5474 venchmark: 1.5492 acc:  0.502
# 485 agent: 1.1645 venchmark: 1.1694 acc:  0.5021
# 486 agent: 0.9324 venchmark: 0.9153 acc:  0.5022
# 487 agent: 0.8313 venchmark: 0.8159 acc:  0.5022
# 488 agent: 0.9712 venchmark: 0.9748 acc:  0.5022
# 489 agent: 1.3477 venchmark: 1.3698 acc:  0.5022
# 490 agent: 0.9172 venchmark: 0.9302 acc:  0.5023
# 491 agent: 1.0164 venchmark: 1.0277 acc:  0.5023
# 492 agent: 1.1399 venchmark: 1.1175 acc:  0.5024
# 493 agent: 1.105 venchmark: 1.1191 acc:  0.5024
# 494 agent: 1.3492 venchmark: 1.3308 acc:  0.5024
# 495 agent: 1.2328 venchmark: 1.2354 acc:  0.5024
# 496 agent: 1.143 venchmark: 1.1192 acc:  0.5025
# 497 agent: 1.1158 venchmark: 1.1053 acc:  0.5024
# 498 agent: 1.0073 venchmark: 1.0186 acc:  0.5024
# 499 agent: 1.0142 venchmark: 1.0344 acc:  0.5024
# saved
# average return:  5.35000000000001 %
# AAM loss: -7.231114864349365 ESM loss: 1976928.122958064
# 500 agent: 1.1211 venchmark: 1.1479 acc:  0.5024
# 501 agent: 1.1665 venchmark: 1.1476 acc:  0.5024
# 502 agent: 1.0324 venchmark: 1.0343 acc:  0.5025
# 503 agent: 0.9551 venchmark: 0.9347 acc:  0.5026
# 504 agent: 1.1655 venchmark: 1.1421 acc:  0.5025
# 505 agent: 1.0933 venchmark: 1.1103 acc:  0.5024
# 506 agent: 0.8424 venchmark: 0.8205 acc:  0.5025
# 507 agent: 1.0355 venchmark: 1.0557 acc:  0.5025
# 508 agent: 1.3283 venchmark: 1.3297 acc:  0.5025
# 509 agent: 1.328 venchmark: 1.3472 acc:  0.5024
# 510 agent: 1.1452 venchmark: 1.1799 acc:  0.5024
# 511 agent: 1.3801 venchmark: 1.3843 acc:  0.5025
# 512 agent: 1.688 venchmark: 1.7022 acc:  0.5024
# 513 agent: 0.9825 venchmark: 0.9851 acc:  0.5024
# 514 agent: 1.0596 venchmark: 1.0978 acc:  0.5024
# 515 agent: 0.8934 venchmark: 0.8964 acc:  0.5024
# 516 agent: 0.7799 venchmark: 0.7854 acc:  0.5023
# 517 agent: 0.935 venchmark: 0.9276 acc:  0.5024
# 518 agent: 1.2208 venchmark: 1.2008 acc:  0.5024
# 519 agent: 1.3639 venchmark: 1.3426 acc:  0.5025
# 520 agent: 0.8083 venchmark: 0.8018 acc:  0.5024
# 521 agent: 1.4234 venchmark: 1.4292 acc:  0.5024
# 522 agent: 1.1208 venchmark: 1.1392 acc:  0.5024
# 523 agent: 1.1633 venchmark: 1.1658 acc:  0.5025
# 524 agent: 1.6876 venchmark: 1.7236 acc:  0.5025
# 525 agent: 0.8741 venchmark: 0.8791 acc:  0.5025
# 526 agent: 0.8937 venchmark: 0.8971 acc:  0.5026
# 527 agent: 1.299 venchmark: 1.3079 acc:  0.5026
# 528 agent: 1.3033 venchmark: 1.2717 acc:  0.5027
# 529 agent: 1.245 venchmark: 1.2395 acc:  0.5027
# 530 agent: 1.0698 venchmark: 1.0633 acc:  0.5028
# 531 agent: 1.0069 venchmark: 0.9921 acc:  0.5028
# 532 agent: 1.2763 venchmark: 1.2453 acc:  0.5028
# 533 agent: 1.4765 venchmark: 1.4438 acc:  0.5028
# 534 agent: 0.9015 venchmark: 0.9091 acc:  0.5029
# 535 agent: 0.9456 venchmark: 0.9345 acc:  0.5028
# 536 agent: 0.8455 venchmark: 0.8232 acc:  0.5028
# 537 agent: 0.9241 venchmark: 0.9125 acc:  0.5028
# 538 agent: 1.0005 venchmark: 1.039 acc:  0.5028
# 539 agent: 1.1464 venchmark: 1.15 acc:  0.5028
# 540 agent: 0.9707 venchmark: 0.9594 acc:  0.5028
# 541 agent: 0.5946 venchmark: 0.5812 acc:  0.5028
# 542 agent: 1.2052 venchmark: 1.2008 acc:  0.5028
# 543 agent: 1.136 venchmark: 1.1042 acc:  0.5028
# 544 agent: 1.3565 venchmark: 1.3639 acc:  0.5028
# 545 agent: 1.8115 venchmark: 1.7846 acc:  0.5028
# 546 agent: 1.3928 venchmark: 1.3974 acc:  0.5029
# 547 agent: 1.2566 venchmark: 1.2353 acc:  0.503
# 548 agent: 1.1394 venchmark: 1.1122 acc:  0.503
# 549 agent: 1.0767 venchmark: 1.0621 acc:  0.503
# 550 agent: 1.1982 venchmark: 1.2053 acc:  0.503
# 551 agent: 0.8612 venchmark: 0.8194 acc:  0.503
# 552 agent: 1.3221 venchmark: 1.3206 acc:  0.503
# 553 agent: 1.1533 venchmark: 1.1461 acc:  0.503
# 554 agent: 0.9897 venchmark: 0.9925 acc:  0.503
# 555 agent: 0.915 venchmark: 0.9551 acc:  0.5031
# 556 agent: 1.1882 venchmark: 1.2239 acc:  0.5031
# 557 agent: 0.7536 venchmark: 0.7548 acc:  0.5031
# 558 agent: 1.6468 venchmark: 1.6345 acc:  0.5031
# 559 agent: 0.9729 venchmark: 0.9932 acc:  0.5032
# 560 agent: 1.6437 venchmark: 1.6524 acc:  0.5032
# 561 agent: 0.8814 venchmark: 0.886 acc:  0.5032
# 562 agent: 0.5944 venchmark: 0.5876 acc:  0.5032
# 563 agent: 1.1082 venchmark: 1.1045 acc:  0.5032
# 564 agent: 0.9347 venchmark: 0.9236 acc:  0.5032
# 565 agent: 0.975 venchmark: 1.0025 acc:  0.5033
# 566 agent: 1.379 venchmark: 1.3591 acc:  0.5033
# 567 agent: 0.859 venchmark: 0.8578 acc:  0.5034
# 568 agent: 1.158 venchmark: 1.1608 acc:  0.5033
# 569 agent: 0.8722 venchmark: 0.8435 acc:  0.5034
# 570 agent: 1.1406 venchmark: 1.0896 acc:  0.5034
# 571 agent: 1.1456 venchmark: 1.1329 acc:  0.5034
# 572 agent: 1.1856 venchmark: 1.21 acc:  0.5033
# 573 agent: 1.3048 venchmark: 1.2813 acc:  0.5034
# 574 agent: 1.584 venchmark: 1.5695 acc:  0.5034
# 575 agent: 1.5502 venchmark: 1.5788 acc:  0.5034
# 576 agent: 1.2032 venchmark: 1.179 acc:  0.5034
# 577 agent: 0.9567 venchmark: 0.9372 acc:  0.5034
# 578 agent: 1.0499 venchmark: 1.0976 acc:  0.5034
# 579 agent: 0.9868 venchmark: 1.0509 acc:  0.5035
# 580 agent: 1.2316 venchmark: 1.2128 acc:  0.5035
# 581 agent: 1.4201 venchmark: 1.4775 acc:  0.5036
# 582 agent: 1.4742 venchmark: 1.4728 acc:  0.5037
# 583 agent: 1.0385 venchmark: 1.0157 acc:  0.5038
# 584 agent: 0.9731 venchmark: 1.0435 acc:  0.5038
# 585 agent: 1.0785 venchmark: 1.0762 acc:  0.5037
# 586 agent: 1.0569 venchmark: 1.0267 acc:  0.5038
# 587 agent: 1.2004 venchmark: 1.174 acc:  0.5037
# 588 agent: 0.8593 venchmark: 0.8758 acc:  0.5038
# 589 agent: 1.1866 venchmark: 1.2258 acc:  0.5038
# 590 agent: 1.1964 venchmark: 1.1542 acc:  0.5038
# 591 agent: 0.9113 venchmark: 0.8544 acc:  0.5038
# 592 agent: 1.4081 venchmark: 1.4623 acc:  0.5039
# 593 agent: 1.1569 venchmark: 1.1744 acc:  0.5039
# 594 agent: 0.8076 venchmark: 0.7714 acc:  0.5038
# 595 agent: 1.5703 venchmark: 1.4902 acc:  0.5038
# 596 agent: 0.8647 venchmark: 0.8597 acc:  0.5038
# 597 agent: 0.9605 venchmark: 0.9512 acc:  0.5038
# 598 agent: 0.9458 venchmark: 0.8897 acc:  0.5038
# 599 agent: 1.4956 venchmark: 1.5947 acc:  0.5038
# saved
# average return:  13.22000000000001 %
# AAM loss: -26.16678372770548 ESM loss: 1976328.2967225611
# 600 agent: 1.0453 venchmark: 1.0467 acc:  0.5038
# 601 agent: 1.1179 venchmark: 1.0843 acc:  0.5038
# 602 agent: 1.5577 venchmark: 1.486 acc:  0.5039
# 603 agent: 0.8218 venchmark: 0.8839 acc:  0.5039
# 604 agent: 1.1526 venchmark: 1.2008 acc:  0.5039
# 605 agent: 1.0413 venchmark: 0.9692 acc:  0.504
# 606 agent: 1.2374 venchmark: 1.2255 acc:  0.504
# 607 agent: 1.1665 venchmark: 1.0771 acc:  0.5041
# 608 agent: 0.8034 venchmark: 0.7825 acc:  0.504
# 609 agent: 0.8227 venchmark: 0.8633 acc:  0.5041
# 610 agent: 0.7942 venchmark: 0.7819 acc:  0.5041
# 611 agent: 2.0131 venchmark: 1.9485 acc:  0.504
# 612 agent: 1.0358 venchmark: 1.0523 acc:  0.504
# 613 agent: 1.0866 venchmark: 1.1396 acc:  0.504
# 614 agent: 0.9377 venchmark: 0.9738 acc:  0.5041
# 615 agent: 0.7112 venchmark: 0.7095 acc:  0.5041
# 616 agent: 1.0982 venchmark: 1.1024 acc:  0.5042
# 617 agent: 1.0106 venchmark: 1.0333 acc:  0.5041
# 618 agent: 1.1422 venchmark: 1.1655 acc:  0.5041
# 619 agent: 1.151 venchmark: 1.1671 acc:  0.5041
# 620 agent: 1.2535 venchmark: 1.2021 acc:  0.5041
# 621 agent: 0.8331 venchmark: 0.8702 acc:  0.5041
# 622 agent: 0.9232 venchmark: 0.9492 acc:  0.5041
# 623 agent: 0.838 venchmark: 0.8283 acc:  0.5041
# 624 agent: 0.9784 venchmark: 0.9654 acc:  0.5041
# 625 agent: 0.6874 venchmark: 0.7049 acc:  0.5041
# 626 agent: 1.1441 venchmark: 1.1066 acc:  0.5041
# 627 agent: 1.1659 venchmark: 1.1463 acc:  0.5041
# 628 agent: 0.9628 venchmark: 0.9578 acc:  0.5042
# 629 agent: 1.033 venchmark: 0.9645 acc:  0.5042
# 630 agent: 0.8618 venchmark: 0.8984 acc:  0.5042
# 631 agent: 0.9804 venchmark: 0.9816 acc:  0.5043
# 632 agent: 1.1542 venchmark: 1.1413 acc:  0.5042
# 633 agent: 0.965 venchmark: 0.9826 acc:  0.5042
# 634 agent: 0.8929 venchmark: 0.8432 acc:  0.5042
# 635 agent: 1.2897 venchmark: 1.2929 acc:  0.5043
# 636 agent: 1.1803 venchmark: 1.2275 acc:  0.5044
# 637 agent: 1.0979 venchmark: 1.1409 acc:  0.5045
# 638 agent: 0.7637 venchmark: 0.7858 acc:  0.5045
# 639 agent: 1.2033 venchmark: 1.1463 acc:  0.5045
# 640 agent: 1.0395 venchmark: 1.0727 acc:  0.5046
# 641 agent: 1.169 venchmark: 1.2179 acc:  0.5047
# 642 agent: 1.0139 venchmark: 0.9936 acc:  0.5047
# 643 agent: 1.5977 venchmark: 1.5042 acc:  0.5047
# 644 agent: 1.0767 venchmark: 1.0455 acc:  0.5047
# 645 agent: 0.9087 venchmark: 0.8959 acc:  0.5048
# 646 agent: 1.3265 venchmark: 1.3481 acc:  0.5047
# 647 agent: 1.6362 venchmark: 1.6507 acc:  0.5047
# 648 agent: 1.033 venchmark: 1.0016 acc:  0.5047
# 649 agent: 0.7474 venchmark: 0.7518 acc:  0.5047
# 650 agent: 1.0243 venchmark: 1.0149 acc:  0.5046
# 651 agent: 1.0487 venchmark: 1.0823 acc:  0.5047
# 652 agent: 0.9418 venchmark: 0.9724 acc:  0.5046
# 653 agent: 1.0865 venchmark: 1.0901 acc:  0.5046
# 654 agent: 1.1693 venchmark: 1.149 acc:  0.5047
# 655 agent: 1.1118 venchmark: 1.1046 acc:  0.5047
# 656 agent: 0.9461 venchmark: 0.9441 acc:  0.5047
# 657 agent: 1.2763 venchmark: 1.2718 acc:  0.5047
# 658 agent: 1.0932 venchmark: 1.1035 acc:  0.5047
# 659 agent: 1.0488 venchmark: 1.0585 acc:  0.5047
# 660 agent: 1.3377 venchmark: 1.2671 acc:  0.5047
# 661 agent: 0.9652 venchmark: 0.9005 acc:  0.5047
# 662 agent: 1.8775 venchmark: 1.7744 acc:  0.5047
# 663 agent: 0.795 venchmark: 0.782 acc:  0.5047
# 664 agent: 1.0356 venchmark: 1.0315 acc:  0.5047
# 665 agent: 1.2569 venchmark: 1.259 acc:  0.5047
# 666 agent: 1.0893 venchmark: 1.0216 acc:  0.5047
# 667 agent: 1.2727 venchmark: 1.1959 acc:  0.5047
# 668 agent: 1.1522 venchmark: 1.0625 acc:  0.5047
# 669 agent: 1.1137 venchmark: 1.3002 acc:  0.5048
# 670 agent: 1.5029 venchmark: 1.4005 acc:  0.5048
# 671 agent: 0.9651 venchmark: 1.0786 acc:  0.5048
# 672 agent: 1.222 venchmark: 1.1839 acc:  0.5048
# 673 agent: 1.1186 venchmark: 1.0662 acc:  0.5048
# 674 agent: 1.0138 venchmark: 0.9916 acc:  0.5048
# 675 agent: 1.2964 venchmark: 1.2286 acc:  0.5048
# 676 agent: 1.1406 venchmark: 1.1295 acc:  0.5048
# 677 agent: 0.8218 venchmark: 0.8363 acc:  0.5049
# 678 agent: 1.1238 venchmark: 1.2453 acc:  0.5049
# 679 agent: 0.9461 venchmark: 0.8927 acc:  0.5049
# 680 agent: 0.8342 venchmark: 0.8408 acc:  0.505
# 681 agent: 0.7181 venchmark: 0.84 acc:  0.505
# 682 agent: 1.0764 venchmark: 1.0434 acc:  0.505
# 683 agent: 0.7998 venchmark: 0.8936 acc:  0.505
# 684 agent: 1.1076 venchmark: 1.1279 acc:  0.505
# 685 agent: 1.1267 venchmark: 1.0611 acc:  0.505
# 686 agent: 0.7409 venchmark: 0.767 acc:  0.505
# 687 agent: 0.7296 venchmark: 0.6651 acc:  0.5051
# 688 agent: 1.0232 venchmark: 0.9748 acc:  0.5051
# 689 agent: 1.5298 venchmark: 1.4181 acc:  0.5052
# 690 agent: 0.8778 venchmark: 0.8279 acc:  0.5052
# 691 agent: 0.8707 venchmark: 0.877 acc:  0.5052
# 692 agent: 1.1941 venchmark: 1.2605 acc:  0.5052
# 693 agent: 1.6175 venchmark: 1.7408 acc:  0.5053
# 694 agent: 1.2835 venchmark: 1.1637 acc:  0.5054
# 695 agent: 1.3961 venchmark: 1.5178 acc:  0.5054
# 696 agent: 1.5617 venchmark: 1.4827 acc:  0.5053
# 697 agent: 1.217 venchmark: 1.2494 acc:  0.5053
# 698 agent: 1.4323 venchmark: 1.3255 acc:  0.5053
# 699 agent: 1.282 venchmark: 1.3173 acc:  0.5053
# saved
# average return:  9.719999999999995 %
# AAM loss: -47.18212115764618 ESM loss: 1975832.1404603422
# 700 agent: 1.548 venchmark: 1.6971 acc:  0.5053
# 701 agent: 1.388 venchmark: 1.4281 acc:  0.5053
# 702 agent: 0.8609 venchmark: 0.9468 acc:  0.5053
# 703 agent: 1.0528 venchmark: 0.984 acc:  0.5053
# 704 agent: 1.4734 venchmark: 1.6864 acc:  0.5054
# 705 agent: 1.24 venchmark: 1.2673 acc:  0.5054
# 706 agent: 0.7081 venchmark: 0.6946 acc:  0.5054
# 707 agent: 0.9474 venchmark: 0.9648 acc:  0.5054
# 708 agent: 0.8971 venchmark: 0.9022 acc:  0.5055
# 709 agent: 1.3982 venchmark: 1.2794 acc:  0.5054
# 710 agent: 0.9027 venchmark: 0.9287 acc:  0.5053
# 711 agent: 1.0069 venchmark: 0.9601 acc:  0.5054
# 712 agent: 1.3107 venchmark: 1.2522 acc:  0.5054
# 713 agent: 0.9402 venchmark: 0.929 acc:  0.5054
# 714 agent: 0.642 venchmark: 0.6408 acc:  0.5055
# 715 agent: 1.2751 venchmark: 1.1653 acc:  0.5055
# 716 agent: 1.2205 venchmark: 1.2814 acc:  0.5055
# 717 agent: 1.5204 venchmark: 1.3934 acc:  0.5055
# 718 agent: 1.2692 venchmark: 1.3761 acc:  0.5056
# 719 agent: 0.8791 venchmark: 0.9566 acc:  0.5057
# 720 agent: 0.8924 venchmark: 0.9021 acc:  0.5057
# 721 agent: 1.1018 venchmark: 1.0156 acc:  0.5058
# 722 agent: 0.8435 venchmark: 0.9222 acc:  0.5058
# 723 agent: 1.5213 venchmark: 1.5204 acc:  0.5059
# 724 agent: 1.1826 venchmark: 1.052 acc:  0.5059
# 725 agent: 1.238 venchmark: 1.2077 acc:  0.5059
# 726 agent: 1.0431 venchmark: 0.8839 acc:  0.5059
# 727 agent: 0.9563 venchmark: 0.9646 acc:  0.506
# 728 agent: 0.9623 venchmark: 0.8666 acc:  0.506
# 729 agent: 1.098 venchmark: 1.2124 acc:  0.506
# 730 agent: 0.9025 venchmark: 0.8173 acc:  0.5061
# 731 agent: 1.0078 venchmark: 0.9958 acc:  0.5061
# 732 agent: 1.3596 venchmark: 1.1025 acc:  0.5061
# 733 agent: 1.5155 venchmark: 1.3214 acc:  0.5061
# 734 agent: 1.153 venchmark: 1.1394 acc:  0.5062
# 735 agent: 1.339 venchmark: 1.4735 acc:  0.5062
# 736 agent: 1.1443 venchmark: 0.9685 acc:  0.5062
# 737 agent: 0.9418 venchmark: 1.2815 acc:  0.5062
# 738 agent: 1.5966 venchmark: 1.2291 acc:  0.5063
# 739 agent: 1.2123 venchmark: 1.3851 acc:  0.5063
# 740 agent: 1.2707 venchmark: 1.5167 acc:  0.5062
# 741 agent: 1.2313 venchmark: 1.1079 acc:  0.5062
# 742 agent: 1.1103 venchmark: 0.9352 acc:  0.5062
# 743 agent: 0.7642 venchmark: 1.0892 acc:  0.5062
# 744 agent: 1.0315 venchmark: 0.9069 acc:  0.5063
# 745 agent: 1.2032 venchmark: 1.0276 acc:  0.5063
# 746 agent: 0.6454 venchmark: 0.7371 acc:  0.5062
# 747 agent: 1.2533 venchmark: 1.2644 acc:  0.5062
# 748 agent: 1.048 venchmark: 0.9154 acc:  0.5062
# 749 agent: 1.4338 venchmark: 1.5487 acc:  0.5062
# 750 agent: 1.8467 venchmark: 1.681 acc:  0.5063
# 751 agent: 0.8945 venchmark: 1.0042 acc:  0.5063
# 752 agent: 0.8099 venchmark: 0.733 acc:  0.5063
# 753 agent: 0.9839 venchmark: 0.8913 acc:  0.5063
# 754 agent: 1.26 venchmark: 1.3442 acc:  0.5063
# 755 agent: 1.5876 venchmark: 1.646 acc:  0.5063
# 756 agent: 1.4005 venchmark: 1.4293 acc:  0.5064
# 757 agent: 1.457 venchmark: 1.406 acc:  0.5064
# 758 agent: 1.3478 venchmark: 1.304 acc:  0.5065
# 759 agent: 1.1391 venchmark: 1.0138 acc:  0.5064
# 760 agent: 1.449 venchmark: 1.2372 acc:  0.5064
# 761 agent: 1.0184 venchmark: 1.1023 acc:  0.5065
# 762 agent: 1.1365 venchmark: 0.9079 acc:  0.5065
# 763 agent: 1.429 venchmark: 1.3774 acc:  0.5065
# 764 agent: 1.4504 venchmark: 1.1663 acc:  0.5066
# 765 agent: 1.4307 venchmark: 1.2887 acc:  0.5066
# 766 agent: 1.472 venchmark: 1.6187 acc:  0.5067
# 767 agent: 0.8865 venchmark: 0.9459 acc:  0.5066
# 768 agent: 0.6151 venchmark: 0.8247 acc:  0.5066
# 769 agent: 1.2061 venchmark: 0.983 acc:  0.5067
# 770 agent: 1.0062 venchmark: 0.921 acc:  0.5067
# 771 agent: 1.04 venchmark: 0.9901 acc:  0.5067
# 772 agent: 1.2382 venchmark: 1.0313 acc:  0.5067
# 773 agent: 1.2606 venchmark: 1.3862 acc:  0.5067
# 774 agent: 1.8471 venchmark: 1.502 acc:  0.5068
# 775 agent: 1.2001 venchmark: 1.158 acc:  0.5067
# 776 agent: 1.046 venchmark: 1.0901 acc:  0.5068
# 777 agent: 1.5895 venchmark: 1.7168 acc:  0.5068
# 778 agent: 1.5039 venchmark: 1.4291 acc:  0.5068
# 779 agent: 1.1006 venchmark: 1.0609 acc:  0.5068
# 780 agent: 1.3115 venchmark: 1.031 acc:  0.5069
# 781 agent: 0.8633 venchmark: 0.9079 acc:  0.5068
# 782 agent: 0.6035 venchmark: 0.7842 acc:  0.5068
# 783 agent: 1.0128 venchmark: 0.9805 acc:  0.5068
# 784 agent: 1.7958 venchmark: 1.2392 acc:  0.5068
# 785 agent: 1.2092 venchmark: 1.0375 acc:  0.5068
# 786 agent: 0.5059 venchmark: 0.7267 acc:  0.5069
# 787 agent: 0.8878 venchmark: 1.2112 acc:  0.5068
# 788 agent: 1.3475 venchmark: 1.6382 acc:  0.5068
# 789 agent: 1.3209 venchmark: 1.3488 acc:  0.5068
# 790 agent: 1.0463 venchmark: 1.0183 acc:  0.5069
# 791 agent: 1.1539 venchmark: 1.0125 acc:  0.507
# 792 agent: 1.143 venchmark: 0.9642 acc:  0.507
# 793 agent: 1.0512 venchmark: 1.3536 acc:  0.507
# 794 agent: 0.9268 venchmark: 1.4499 acc:  0.507
# 795 agent: 1.5631 venchmark: 1.1662 acc:  0.5071
# 796 agent: 1.4151 venchmark: 1.2208 acc:  0.5071
# 797 agent: 1.7193 venchmark: 1.66 acc:  0.5071
# 798 agent: 1.4239 venchmark: 1.2197 acc:  0.5071
# 799 agent: 0.648 venchmark: 0.865 acc:  0.5071
# saved
# average return:  17.090000000000003 %
# AAM loss: -224.55210834741592 ESM loss: 1975420.651907295
# 800 agent: 1.4821 venchmark: 1.1817 acc:  0.5072
# 801 agent: 1.0544 venchmark: 1.0106 acc:  0.5072
# 802 agent: 1.4789 venchmark: 1.5399 acc:  0.5072
# 803 agent: 0.7022 venchmark: 1.0641 acc:  0.5072
# 804 agent: 0.778 venchmark: 0.9554 acc:  0.5072
# 805 agent: 0.7063 venchmark: 0.8084 acc:  0.5073
# 806 agent: 1.1254 venchmark: 0.9475 acc:  0.5073
# 807 agent: 0.8287 venchmark: 0.8994 acc:  0.5073
# 808 agent: 0.9786 venchmark: 0.9256 acc:  0.5073
# 809 agent: 1.2882 venchmark: 1.1442 acc:  0.5073
# 810 agent: 1.1325 venchmark: 1.1247 acc:  0.5073
# 811 agent: 1.4916 venchmark: 1.1803 acc:  0.5073
# 812 agent: 1.1743 venchmark: 1.2005 acc:  0.5074
# 813 agent: 0.8263 venchmark: 0.8997 acc:  0.5073
# 814 agent: 1.279 venchmark: 1.3443 acc:  0.5074
# 815 agent: 1.1154 venchmark: 1.148 acc:  0.5074
# 816 agent: 0.7554 venchmark: 0.8651 acc:  0.5074
# 817 agent: 1.0989 venchmark: 1.1548 acc:  0.5075
# 818 agent: 1.475 venchmark: 1.4396 acc:  0.5075
# 819 agent: 0.9396 venchmark: 1.2382 acc:  0.5075
# 820 agent: 1.1839 venchmark: 1.1996 acc:  0.5075
# 821 agent: 1.4526 venchmark: 1.3093 acc:  0.5076
# 822 agent: 1.0866 venchmark: 0.8466 acc:  0.5076
# 823 agent: 1.2345 venchmark: 1.3324 acc:  0.5076
# 824 agent: 0.693 venchmark: 0.7714 acc:  0.5077
# 825 agent: 1.7269 venchmark: 1.6183 acc:  0.5077
# 826 agent: 1.6407 venchmark: 1.1738 acc:  0.5077
# 827 agent: 1.0542 venchmark: 1.1289 acc:  0.5077
# 828 agent: 0.9574 venchmark: 1.0165 acc:  0.5077
# 829 agent: 1.0613 venchmark: 1.272 acc:  0.5077
# 830 agent: 1.0021 venchmark: 0.9897 acc:  0.5077
# 831 agent: 1.755 venchmark: 1.4337 acc:  0.5077
# 832 agent: 1.2344 venchmark: 1.1495 acc:  0.5077
# 833 agent: 0.9889 venchmark: 1.0834 acc:  0.5077
# 834 agent: 1.1136 venchmark: 1.0886 acc:  0.5077
# 835 agent: 0.9891 venchmark: 0.9482 acc:  0.5077
# 836 agent: 0.6804 venchmark: 1.0302 acc:  0.5077
# 837 agent: 1.1896 venchmark: 1.2641 acc:  0.5078
# 838 agent: 1.3407 venchmark: 1.2774 acc:  0.5078
# 839 agent: 1.8176 venchmark: 1.5743 acc:  0.5078
# 840 agent: 1.3971 venchmark: 1.2978 acc:  0.5078
# 841 agent: 1.0689 venchmark: 1.2117 acc:  0.5078
# 842 agent: 1.1209 venchmark: 0.8669 acc:  0.5079
# 843 agent: 1.1355 venchmark: 1.2052 acc:  0.5079
# 844 agent: 1.4729 venchmark: 1.2493 acc:  0.5079
# 845 agent: 1.2305 venchmark: 1.3528 acc:  0.5079
# 846 agent: 0.9163 venchmark: 0.99 acc:  0.5079
# 847 agent: 1.0798 venchmark: 1.2556 acc:  0.5079
# 848 agent: 0.6688 venchmark: 0.8718 acc:  0.5079
# 849 agent: 0.9224 venchmark: 0.8714 acc:  0.508
# 850 agent: 0.8869 venchmark: 0.8981 acc:  0.5081
# 851 agent: 1.2603 venchmark: 1.4899 acc:  0.5081
# 852 agent: 1.0866 venchmark: 0.8382 acc:  0.5081
# 853 agent: 0.9834 venchmark: 1.0741 acc:  0.5079
# 854 agent: 1.3531 venchmark: 1.4789 acc:  0.5079
# 855 agent: 0.9664 venchmark: 0.9675 acc:  0.5079
# 856 agent: 1.5165 venchmark: 1.2947 acc:  0.5079
# 857 agent: 0.8411 venchmark: 0.8716 acc:  0.5079
# 858 agent: 0.7745 venchmark: 0.8831 acc:  0.508
# 859 agent: 0.9198 venchmark: 0.8481 acc:  0.5079
# 860 agent: 1.6605 venchmark: 1.4374 acc:  0.5079
# 861 agent: 0.664 venchmark: 0.843 acc:  0.5079
# 862 agent: 0.8615 venchmark: 1.2446 acc:  0.5079
# 863 agent: 0.7757 venchmark: 1.0107 acc:  0.5079
# 864 agent: 0.9601 venchmark: 1.0191 acc:  0.508
# 865 agent: 1.1136 venchmark: 1.1896 acc:  0.5081
# 866 agent: 0.6354 venchmark: 0.7314 acc:  0.5081
# 867 agent: 1.2252 venchmark: 1.1287 acc:  0.5081
# 868 agent: 1.3538 venchmark: 1.2722 acc:  0.5081
# 869 agent: 1.0167 venchmark: 1.0725 acc:  0.508
# 870 agent: 0.9346 venchmark: 0.7386 acc:  0.5081
# 871 agent: 1.4695 venchmark: 1.2184 acc:  0.5081
# 872 agent: 1.3261 venchmark: 0.9172 acc:  0.5081
# 873 agent: 0.8388 venchmark: 0.872 acc:  0.5081
# 874 agent: 0.8482 venchmark: 0.7654 acc:  0.5081
# 875 agent: 1.1195 venchmark: 1.2678 acc:  0.5082
# 876 agent: 1.0762 venchmark: 0.9032 acc:  0.5082
# 877 agent: 0.959 venchmark: 1.1258 acc:  0.5082
# 878 agent: 0.703 venchmark: 1.2174 acc:  0.5082
# 879 agent: 1.4439 venchmark: 1.3437 acc:  0.5082
# 880 agent: 1.0656 venchmark: 1.0809 acc:  0.5082
# 881 agent: 0.9968 venchmark: 1.0704 acc:  0.5083
# 882 agent: 1.1833 venchmark: 1.1158 acc:  0.5083
# 883 agent: 0.9764 venchmark: 1.1581 acc:  0.5083
# 884 agent: 1.127 venchmark: 1.1254 acc:  0.5083
# 885 agent: 1.7151 venchmark: 1.4838 acc:  0.5083
# 886 agent: 0.783 venchmark: 0.9512 acc:  0.5083
# 887 agent: 0.7634 venchmark: 1.023 acc:  0.5083
# 888 agent: 0.8373 venchmark: 0.8963 acc:  0.5083
# 889 agent: 0.9379 venchmark: 1.0345 acc:  0.5083
# 890 agent: 1.6344 venchmark: 1.3957 acc:  0.5083
# 891 agent: 0.9264 venchmark: 0.7927 acc:  0.5083
# 892 agent: 1.0279 venchmark: 0.8541 acc:  0.5083
# 893 agent: 0.928 venchmark: 1.0267 acc:  0.5083
# 894 agent: 0.9806 venchmark: 0.8104 acc:  0.5083
# 895 agent: 1.4339 venchmark: 1.6794 acc:  0.5083
# 896 agent: 1.6016 venchmark: 1.1071 acc:  0.5084
# 897 agent: 1.0073 venchmark: 0.7961 acc:  0.5084
# 898 agent: 1.6939 venchmark: 1.5155 acc:  0.5084
# 899 agent: 0.938 venchmark: 0.9168 acc:  0.5085
# saved
# average return:  11.060000000000002 %
# AAM loss: -84.19437512755394 ESM loss: 1975074.8704620898
# 900 agent: 2.1821 venchmark: 1.5594 acc:  0.5085
# 901 agent: 0.5648 venchmark: 0.899 acc:  0.5085
# 902 agent: 1.3368 venchmark: 0.9081 acc:  0.5085
# 903 agent: 2.3256 venchmark: 1.6934 acc:  0.5085
# 904 agent: 0.9548 venchmark: 0.7148 acc:  0.5086
# 905 agent: 0.6141 venchmark: 0.7648 acc:  0.5086
# 906 agent: 0.8623 venchmark: 1.1123 acc:  0.5086
# 907 agent: 1.3041 venchmark: 0.9683 acc:  0.5086
# 908 agent: 0.908 venchmark: 1.0513 acc:  0.5086
# 909 agent: 1.3474 venchmark: 1.0869 acc:  0.5087
# 910 agent: 2.191 venchmark: 1.2762 acc:  0.5087
# 911 agent: 1.1223 venchmark: 1.0606 acc:  0.5086
# 912 agent: 0.6903 venchmark: 1.0454 acc:  0.5087
# 913 agent: 0.9556 venchmark: 1.216 acc:  0.5087
# 914 agent: 1.5964 venchmark: 0.9929 acc:  0.5087
# 915 agent: 1.4096 venchmark: 1.2472 acc:  0.5087
# 916 agent: 0.94 venchmark: 0.9355 acc:  0.5087
# 917 agent: 0.9867 venchmark: 1.235 acc:  0.5087
# 918 agent: 1.0822 venchmark: 1.3306 acc:  0.5087
# 919 agent: 1.0542 venchmark: 1.0882 acc:  0.5088
# 920 agent: 1.8422 venchmark: 1.3129 acc:  0.5088
# 921 agent: 1.0645 venchmark: 1.1517 acc:  0.5088
# 922 agent: 1.4791 venchmark: 1.2004 acc:  0.5088
# 923 agent: 1.3098 venchmark: 1.2347 acc:  0.5088
# 924 agent: 0.8985 venchmark: 0.8861 acc:  0.5088
# 925 agent: 1.8543 venchmark: 1.3547 acc:  0.5088
# 926 agent: 1.1637 venchmark: 1.57 acc:  0.5088
# 927 agent: 0.7539 venchmark: 1.1452 acc:  0.5088
# 928 agent: 0.8988 venchmark: 0.975 acc:  0.5089
# 929 agent: 1.6152 venchmark: 1.2847 acc:  0.5089
# 930 agent: 1.2425 venchmark: 1.1547 acc:  0.5089
# 931 agent: 0.5367 venchmark: 0.7357 acc:  0.509
# 932 agent: 1.5192 venchmark: 1.767 acc:  0.509
# 933 agent: 0.7351 venchmark: 1.0366 acc:  0.5089
# 934 agent: 0.704 venchmark: 1.071 acc:  0.509
# 935 agent: 0.767 venchmark: 0.9884 acc:  0.5091
# 936 agent: 0.865 venchmark: 0.7152 acc:  0.509
# 937 agent: 1.2435 venchmark: 1.0563 acc:  0.509
# 938 agent: 0.6165 venchmark: 1.1295 acc:  0.5089
# 939 agent: 0.7062 venchmark: 0.9925 acc:  0.509
# 940 agent: 1.5391 venchmark: 0.961 acc:  0.5089
# 941 agent: 0.4906 venchmark: 0.7136 acc:  0.5089
# 942 agent: 0.7452 venchmark: 0.8898 acc:  0.5089
# 943 agent: 1.0443 venchmark: 0.9924 acc:  0.5088
# 944 agent: 0.833 venchmark: 1.0336 acc:  0.5088
# 945 agent: 0.4403 venchmark: 0.7733 acc:  0.5088
# 946 agent: 1.1402 venchmark: 1.1188 acc:  0.5089
# 947 agent: 0.6993 venchmark: 1.0574 acc:  0.5089
# 948 agent: 0.9855 venchmark: 1.0035 acc:  0.5089
# 949 agent: 0.9808 venchmark: 0.8532 acc:  0.5089
# 950 agent: 2.5402 venchmark: 1.3893 acc:  0.5089
# 951 agent: 0.695 venchmark: 1.0482 acc:  0.509
# 952 agent: 0.5794 venchmark: 0.9304 acc:  0.5089
# 953 agent: 0.6283 venchmark: 1.5608 acc:  0.5089
# 954 agent: 1.5521 venchmark: 1.3589 acc:  0.5089
# 955 agent: 1.0718 venchmark: 0.8985 acc:  0.5089
# 956 agent: 1.0316 venchmark: 1.4664 acc:  0.5089
# 957 agent: 0.6664 venchmark: 0.9631 acc:  0.509
# 958 agent: 0.9918 venchmark: 1.2872 acc:  0.509
# 959 agent: 0.902 venchmark: 1.2378 acc:  0.5091
# 960 agent: 0.8301 venchmark: 0.8454 acc:  0.5091
# 961 agent: 0.7429 venchmark: 0.8918 acc:  0.5091
# 962 agent: 0.9236 venchmark: 1.0575 acc:  0.5092
# 963 agent: 0.8995 venchmark: 0.8935 acc:  0.5092
# 964 agent: 1.2208 venchmark: 1.1108 acc:  0.5092
# 965 agent: 0.8324 venchmark: 0.7799 acc:  0.5091
# 966 agent: 1.3895 venchmark: 0.9863 acc:  0.5091
# 967 agent: 1.2626 venchmark: 1.3072 acc:  0.5091
# 968 agent: 1.0823 venchmark: 1.0009 acc:  0.5091
# 969 agent: 1.2509 venchmark: 1.3692 acc:  0.5091
# 970 agent: 1.2056 venchmark: 0.9948 acc:  0.5091
# 971 agent: 0.9541 venchmark: 0.9027 acc:  0.5091
# 972 agent: 1.4338 venchmark: 1.447 acc:  0.5091
# 973 agent: 0.9308 venchmark: 0.8303 acc:  0.5092
# 974 agent: 1.2658 venchmark: 1.3794 acc:  0.5092
# 975 agent: 1.2363 venchmark: 1.191 acc:  0.5092
# 976 agent: 0.7219 venchmark: 0.9155 acc:  0.5092
# 977 agent: 0.7824 venchmark: 0.6352 acc:  0.5093
# 978 agent: 0.9709 venchmark: 0.877 acc:  0.5093
# 979 agent: 1.0219 venchmark: 1.4341 acc:  0.5092
# 980 agent: 0.6152 venchmark: 0.83 acc:  0.5093
# 981 agent: 0.7754 venchmark: 0.9165 acc:  0.5093
# 982 agent: 0.7095 venchmark: 0.9503 acc:  0.5093
# 983 agent: 2.2804 venchmark: 1.1883 acc:  0.5093
# 984 agent: 1.2965 venchmark: 1.1083 acc:  0.5093
# 985 agent: 1.1375 venchmark: 0.7871 acc:  0.5093
# 986 agent: 1.284 venchmark: 1.2596 acc:  0.5094
# 987 agent: 1.4187 venchmark: 0.9282 acc:  0.5094
# 988 agent: 0.3957 venchmark: 0.8701 acc:  0.5094
# 989 agent: 1.0629 venchmark: 1.0823 acc:  0.5094
# 990 agent: 1.0154 venchmark: 1.0925 acc:  0.5094
# 991 agent: 1.9082 venchmark: 1.4125 acc:  0.5094
# 992 agent: 0.9057 venchmark: 1.2542 acc:  0.5093
# 993 agent: 1.1672 venchmark: 0.8247 acc:  0.5093
# 994 agent: 1.1886 venchmark: 0.9052 acc:  0.5093
# 995 agent: 1.0332 venchmark: 0.7149 acc:  0.5093
# 996 agent: 0.6848 venchmark: 1.0136 acc:  0.5094
# 997 agent: 1.1041 venchmark: 1.0512 acc:  0.5094
# 998 agent: 0.9488 venchmark: 1.2455 acc:  0.5094
# 999 agent: 1.1462 venchmark: 0.8301 acc:  0.5094
# saved
# average return:  8.840000000000003 %
# AAM loss: -190.19683408737183 ESM loss: 1974773.4976394773
# 1000 agent: 2.045 venchmark: 1.3026 acc:  0.5094
# 1001 agent: 1.0733 venchmark: 1.0539 acc:  0.5094
# 1002 agent: 1.4994 venchmark: 1.4261 acc:  0.5094
# 1003 agent: 0.9155 venchmark: 1.3278 acc:  0.5094
# 1004 agent: 0.4842 venchmark: 1.0963 acc:  0.5093
# 1005 agent: 1.1007 venchmark: 1.0734 acc:  0.5094
# 1006 agent: 1.2369 venchmark: 0.9529 acc:  0.5094
# 1007 agent: 1.196 venchmark: 1.4179 acc:  0.5094
# 1008 agent: 0.6475 venchmark: 1.1869 acc:  0.5094
# 1009 agent: 0.9957 venchmark: 0.8618 acc:  0.5094
# 1010 agent: 0.5003 venchmark: 1.1046 acc:  0.5094
# 1011 agent: 1.2098 venchmark: 1.4383 acc:  0.5094
# 1012 agent: 1.3863 venchmark: 1.142 acc:  0.5094
# 1013 agent: 1.2536 venchmark: 1.1743 acc:  0.5094
# 1014 agent: 1.0527 venchmark: 0.8107 acc:  0.5094
# 1015 agent: 0.8261 venchmark: 0.9021 acc:  0.5094
# 1016 agent: 1.6599 venchmark: 1.2384 acc:  0.5095
# 1017 agent: 0.8467 venchmark: 0.964 acc:  0.5095
# 1018 agent: 0.9424 venchmark: 0.8022 acc:  0.5095
# 1019 agent: 0.8472 venchmark: 0.8551 acc:  0.5095
# 1020 agent: 0.9851 venchmark: 0.9456 acc:  0.5096
# 1021 agent: 1.1673 venchmark: 1.5077 acc:  0.5096
# 1022 agent: 1.7581 venchmark: 1.3373 acc:  0.5096
# 1023 agent: 1.6929 venchmark: 1.5127 acc:  0.5096
# 1024 agent: 2.0949 venchmark: 1.7383 acc:  0.5096
# 1025 agent: 1.9939 venchmark: 1.0146 acc:  0.5096
# 1026 agent: 1.2036 venchmark: 0.8859 acc:  0.5096
# 1027 agent: 1.495 venchmark: 1.1271 acc:  0.5097
# 1028 agent: 1.3417 venchmark: 1.0215 acc:  0.5098
# 1029 agent: 0.5188 venchmark: 0.7921 acc:  0.5098
# 1030 agent: 1.2265 venchmark: 1.2155 acc:  0.5098
# 1031 agent: 1.4667 venchmark: 1.2351 acc:  0.5099
# 1032 agent: 0.9476 venchmark: 1.1647 acc:  0.5098
# 1033 agent: 0.9548 venchmark: 1.0179 acc:  0.5098
# 1034 agent: 1.0332 venchmark: 1.3852 acc:  0.5099
# 1035 agent: 0.905 venchmark: 1.0998 acc:  0.5098
# 1036 agent: 0.9733 venchmark: 1.2896 acc:  0.5098
# 1037 agent: 1.3387 venchmark: 0.9704 acc:  0.5098
# 1038 agent: 0.4708 venchmark: 0.9131 acc:  0.5098
# 1039 agent: 1.7398 venchmark: 1.1958 acc:  0.5098
# 1040 agent: 1.726 venchmark: 1.239 acc:  0.5098
# 1041 agent: 1.6114 venchmark: 1.1349 acc:  0.5098
# 1042 agent: 1.2065 venchmark: 1.522 acc:  0.5098
# 1043 agent: 1.4057 venchmark: 1.1823 acc:  0.5098
# 1044 agent: 0.4867 venchmark: 0.9974 acc:  0.5098
# 1045 agent: 0.7755 venchmark: 1.0351 acc:  0.5098
# 1046 agent: 0.5805 venchmark: 0.8699 acc:  0.5098
# 1047 agent: 0.7718 venchmark: 0.8868 acc:  0.5098
# 1048 agent: 1.3029 venchmark: 0.7963 acc:  0.5098
# 1049 agent: 0.5294 venchmark: 1.1624 acc:  0.5099
# 1050 agent: 0.9184 venchmark: 0.9993 acc:  0.5099
# 1051 agent: 1.455 venchmark: 1.0095 acc:  0.5099
# 1052 agent: 1.4483 venchmark: 0.9118 acc:  0.51
# 1053 agent: 0.5323 venchmark: 0.7964 acc:  0.51
# 1054 agent: 0.8275 venchmark: 1.0435 acc:  0.51
# 1055 agent: 1.3282 venchmark: 1.2295 acc:  0.5101
# 1056 agent: 0.8624 venchmark: 1.1496 acc:  0.51
# 1057 agent: 1.4676 venchmark: 1.3733 acc:  0.5101
# 1058 agent: 0.7916 venchmark: 0.9586 acc:  0.5101
# 1059 agent: 0.4968 venchmark: 0.8022 acc:  0.5101
# 1060 agent: 1.2851 venchmark: 1.2153 acc:  0.5101
# 1061 agent: 0.6514 venchmark: 1.0201 acc:  0.5101
# 1062 agent: 0.8625 venchmark: 0.9141 acc:  0.5101
# 1063 agent: 0.9943 venchmark: 0.8372 acc:  0.5102
# 1064 agent: 1.0238 venchmark: 1.2962 acc:  0.5102
# 1065 agent: 0.5694 venchmark: 1.127 acc:  0.5102
# 1066 agent: 1.241 venchmark: 0.8904 acc:  0.5102
# 1067 agent: 0.9117 venchmark: 1.3298 acc:  0.5102
# 1068 agent: 0.9556 venchmark: 1.1991 acc:  0.5102
# 1069 agent: 0.5368 venchmark: 0.8593 acc:  0.5102
# 1070 agent: 1.2804 venchmark: 0.7566 acc:  0.5102
# 1071 agent: 0.6976 venchmark: 0.8998 acc:  0.5102
# 1072 agent: 0.5024 venchmark: 1.1124 acc:  0.5102
# 1073 agent: 0.7902 venchmark: 0.9318 acc:  0.5101
# 1074 agent: 0.6348 venchmark: 1.0546 acc:  0.5101
# 1075 agent: 0.9266 venchmark: 0.7445 acc:  0.5101
# 1076 agent: 1.8138 venchmark: 1.2217 acc:  0.5101
# 1077 agent: 0.5564 venchmark: 0.9938 acc:  0.5102
# 1078 agent: 0.6215 venchmark: 0.676 acc:  0.5103
# 1079 agent: 1.1209 venchmark: 1.0482 acc:  0.5103
# 1080 agent: 0.5246 venchmark: 0.829 acc:  0.5103
# 1081 agent: 1.5986 venchmark: 1.2315 acc:  0.5104
# 1082 agent: 1.9834 venchmark: 1.1873 acc:  0.5103
# 1083 agent: 0.8413 venchmark: 0.7751 acc:  0.5104
# 1084 agent: 0.5965 venchmark: 0.7944 acc:  0.5104
# 1085 agent: 2.0847 venchmark: 1.4112 acc:  0.5104
# 1086 agent: 1.2769 venchmark: 1.3067 acc:  0.5104
# 1087 agent: 1.1822 venchmark: 0.8893 acc:  0.5104
# 1088 agent: 0.703 venchmark: 1.3341 acc:  0.5104
# 1089 agent: 0.964 venchmark: 1.2207 acc:  0.5104
# 1090 agent: 0.6822 venchmark: 0.8111 acc:  0.5104
# 1091 agent: 0.849 venchmark: 0.9477 acc:  0.5104
# 1092 agent: 1.3528 venchmark: 1.2552 acc:  0.5104
# 1093 agent: 0.8378 venchmark: 0.9498 acc:  0.5105
# 1094 agent: 0.9655 venchmark: 0.7833 acc:  0.5105
# 1095 agent: 0.8876 venchmark: 0.9806 acc:  0.5106
# 1096 agent: 1.2122 venchmark: 1.1021 acc:  0.5106
# 1097 agent: 1.1748 venchmark: 0.9753 acc:  0.5105
# 1098 agent: 1.307 venchmark: 1.1493 acc:  0.5105
# 1099 agent: 0.6832 venchmark: 1.3244 acc:  0.5105
# saved
# average return:  7.230000000000003 %
# AAM loss: 20.0167715549469 ESM loss: 1974503.6455261111
# 1100 agent: 2.1844 venchmark: 1.0592 acc:  0.5105
# 1101 agent: 1.9976 venchmark: 1.0261 acc:  0.5106
# 1102 agent: 1.6692 venchmark: 1.3564 acc:  0.5106
# 1103 agent: 1.8977 venchmark: 1.7702 acc:  0.5106
# 1104 agent: 0.3843 venchmark: 0.9424 acc:  0.5106
# 1105 agent: 0.8221 venchmark: 1.0641 acc:  0.5107
# 1106 agent: 1.6512 venchmark: 1.0674 acc:  0.5107
# 1107 agent: 0.728 venchmark: 0.8164 acc:  0.5108
# 1108 agent: 0.8239 venchmark: 1.3375 acc:  0.5108
# 1109 agent: 0.5043 venchmark: 1.008 acc:  0.5108
# 1110 agent: 3.2002 venchmark: 1.1791 acc:  0.5108
# 1111 agent: 2.8678 venchmark: 1.1884 acc:  0.5109
# 1112 agent: 2.3793 venchmark: 1.3968 acc:  0.5109
# 1113 agent: 0.5645 venchmark: 1.1319 acc:  0.511
# 1114 agent: 1.3944 venchmark: 0.7901 acc:  0.5109
# 1115 agent: 0.7417 venchmark: 0.8926 acc:  0.511
# 1116 agent: 0.1833 venchmark: 0.9699 acc:  0.511
# 1117 agent: 0.5962 venchmark: 1.1836 acc:  0.511
# 1118 agent: 0.704 venchmark: 0.8091 acc:  0.511
# 1119 agent: 0.952 venchmark: 0.9874 acc:  0.5111
# 1120 agent: 0.4391 venchmark: 1.2504 acc:  0.511
# 1121 agent: 1.7694 venchmark: 1.4362 acc:  0.5111
# 1122 agent: 0.7443 venchmark: 0.6953 acc:  0.5112
# 1123 agent: 1.3117 venchmark: 1.1176 acc:  0.5112
# 1124 agent: 0.6728 venchmark: 1.0249 acc:  0.5113
# 1125 agent: 1.384 venchmark: 1.1322 acc:  0.5113
# 1126 agent: 1.4638 venchmark: 1.2658 acc:  0.5113
# 1127 agent: 1.4546 venchmark: 1.0418 acc:  0.5113
# 1128 agent: 2.7524 venchmark: 1.6274 acc:  0.5114
# 1129 agent: 0.3337 venchmark: 0.9227 acc:  0.5114
# 1130 agent: 0.4275 venchmark: 0.993 acc:  0.5114
# 1131 agent: 1.0588 venchmark: 1.1736 acc:  0.5114
# 1132 agent: 1.4972 venchmark: 1.0435 acc:  0.5115
# 1133 agent: 0.5818 venchmark: 0.8674 acc:  0.5115
# 1134 agent: 0.3994 venchmark: 1.1758 acc:  0.5115
# 1135 agent: 0.9348 venchmark: 1.1625 acc:  0.5115
# 1136 agent: 1.117 venchmark: 1.0357 acc:  0.5116
# 1137 agent: 0.9074 venchmark: 1.0274 acc:  0.5115
# 1138 agent: 0.7102 venchmark: 1.1627 acc:  0.5115
# 1139 agent: 1.0164 venchmark: 1.2032 acc:  0.5116
# 1140 agent: 0.5894 venchmark: 1.039 acc:  0.5117
# 1141 agent: 0.9262 venchmark: 1.6513 acc:  0.5117
# 1142 agent: 1.0708 venchmark: 0.926 acc:  0.5117
# 1143 agent: 0.9306 venchmark: 1.1375 acc:  0.5116
# 1144 agent: 0.3402 venchmark: 0.8179 acc:  0.5116
# 1145 agent: 1.8072 venchmark: 1.0754 acc:  0.5116
# 1146 agent: 1.3534 venchmark: 1.5731 acc:  0.5116
# 1147 agent: 2.8873 venchmark: 1.0625 acc:  0.5116
# 1148 agent: 1.3626 venchmark: 0.9131 acc:  0.5115
# 1149 agent: 0.5941 venchmark: 0.916 acc:  0.5115
# 1150 agent: 0.532 venchmark: 0.8163 acc:  0.5114
# 1151 agent: 2.1137 venchmark: 1.5857 acc:  0.5114
# 1152 agent: 1.3389 venchmark: 1.0379 acc:  0.5115
# 1153 agent: 0.5154 venchmark: 1.3746 acc:  0.5115
# 1154 agent: 1.0025 venchmark: 1.0779 acc:  0.5115
# 1155 agent: 0.5349 venchmark: 0.9857 acc:  0.5115
# 1156 agent: 0.6559 venchmark: 0.8344 acc:  0.5115
# 1157 agent: 0.5496 venchmark: 1.1232 acc:  0.5115
# 1158 agent: 1.4435 venchmark: 0.9879 acc:  0.5115
# 1159 agent: 0.9711 venchmark: 0.9287 acc:  0.5116
# 1160 agent: 0.7666 venchmark: 1.126 acc:  0.5116
# 1161 agent: 1.5316 venchmark: 1.2389 acc:  0.5116
# 1162 agent: 1.5101 venchmark: 0.986 acc:  0.5116
# 1163 agent: 1.4774 venchmark: 1.2319 acc:  0.5116
# 1164 agent: 0.812 venchmark: 0.9989 acc:  0.5116
# 1165 agent: 0.6534 venchmark: 1.0554 acc:  0.5116
# 1166 agent: 0.8894 venchmark: 1.4756 acc:  0.5117
# 1167 agent: 1.2286 venchmark: 1.1293 acc:  0.5117
# 1168 agent: 1.7627 venchmark: 1.2378 acc:  0.5117
# 1169 agent: 0.5932 venchmark: 1.221 acc:  0.5117
# 1170 agent: 0.5507 venchmark: 0.882 acc:  0.5118
# 1171 agent: 0.7468 venchmark: 0.9376 acc:  0.5118
# 1172 agent: 0.364 venchmark: 1.1379 acc:  0.5118
# 1173 agent: 0.6091 venchmark: 0.7475 acc:  0.5117
# 1174 agent: 0.6794 venchmark: 0.8715 acc:  0.5117
# 1175 agent: 0.772 venchmark: 0.7722 acc:  0.5118
# 1176 agent: 0.7094 venchmark: 0.9098 acc:  0.5118
# 1177 agent: 1.0603 venchmark: 0.8243 acc:  0.5119
# 1178 agent: 0.534 venchmark: 0.6991 acc:  0.5118
# 1179 agent: 1.2116 venchmark: 1.0213 acc:  0.5119
# 1180 agent: 0.6588 venchmark: 1.0344 acc:  0.5119
# 1181 agent: 0.9932 venchmark: 1.2587 acc:  0.5119
# 1182 agent: 0.7578 venchmark: 1.0549 acc:  0.5119
# 1183 agent: 0.9613 venchmark: 1.0269 acc:  0.512
# 1184 agent: 1.5348 venchmark: 1.1904 acc:  0.512
# 1185 agent: 1.7376 venchmark: 0.9907 acc:  0.512
# 1186 agent: 0.7985 venchmark: 0.9445 acc:  0.512
# 1187 agent: 0.8409 venchmark: 1.4173 acc:  0.5121
# 1188 agent: 1.9091 venchmark: 1.1125 acc:  0.5121
# 1189 agent: 1.2377 venchmark: 0.9312 acc:  0.5121
# 1190 agent: 1.686 venchmark: 1.3135 acc:  0.5121
# ...
# 2282 agent: 0.6678 venchmark: 1.1662 acc:  0.5179
# 2283 agent: 0.5527 venchmark: 0.7058 acc:  0.5179
# 2284 agent: 0.8712 venchmark: 0.9413 acc:  0.5179
# 2285 agent: 0.8375 venchmark: 1.0826 acc:  0.518
# 2286 agent: 1.4297 venchmark: 1.1421 acc:  0.5179
# 2287 agent: 0.5321 venchmark: 1.2919 acc:  0.5179
# 2288 agent: 2.3771 venchmark: 1.4355 acc:  0.5179
# 2289 agent: 1.7801 venchmark: 0.9413 acc:  0.5179
# 2290 agent: 0.3935 venchmark: 0.6067 acc:  0.5179
# 2291 agent: 2.3995 venchmark: 0.8894 acc:  0.5179
# 2292 agent: 0.524 venchmark: 1.3161 acc:  0.5179
# 2293 agent: 0.6995 venchmark: 1.4546 acc:  0.5179
# 2294 agent: 2.3148 venchmark: 1.0864 acc:  0.5179
# 2295 agent: 1.0068 venchmark: 1.697 acc:  0.5179
# 2296 agent: 0.942 venchmark: 1.3965 acc:  0.5178
# 2297 agent: 2.5985 venchmark: 1.0459 acc:  0.5178
# 2298 agent: 0.3839 venchmark: 0.7954 acc:  0.5178
# 2299 agent: 1.1101 venchmark: 0.859 acc:  0.5178
# saved
# average return:  18.43999999999999 %
# AAM loss: -1268.9047446250916 ESM loss: 1972473.5856533349
# 2300 agent: 0.8295 venchmark: 1.0478 acc:  0.5178
# 2301 agent: 2.6993 venchmark: 1.198 acc:  0.5178
# 2302 agent: 0.5326 venchmark: 1.2416 acc:  0.5178
# 2303 agent: 1.9487 venchmark: 1.2004 acc:  0.5178
# 2304 agent: 0.5134 venchmark: 0.6122 acc:  0.5178
# 2305 agent: 0.9352 venchmark: 1.1064 acc:  0.5178
# 2306 agent: 2.1824 venchmark: 0.9143 acc:  0.5178
# 2307 agent: 0.5383 venchmark: 0.8471 acc:  0.5178
# 2308 agent: 1.0419 venchmark: 1.3516 acc:  0.5178
# 2309 agent: 1.4407 venchmark: 1.3448 acc:  0.5178
# 2310 agent: 0.9423 venchmark: 1.0267 acc:  0.5178
# 2311 agent: 1.2505 venchmark: 1.1558 acc:  0.5178
# 2312 agent: 1.1506 venchmark: 1.2004 acc:  0.5178
# 2313 agent: 1.5284 venchmark: 0.9671 acc:  0.5178
# 2314 agent: 1.1196 venchmark: 1.3705 acc:  0.5178
# 2315 agent: 0.8697 venchmark: 0.8289 acc:  0.5178
# 2316 agent: 0.8431 venchmark: 0.9782 acc:  0.5178
# 2317 agent: 1.1007 venchmark: 1.075 acc:  0.5178
# 2318 agent: 1.2199 venchmark: 1.1483 acc:  0.5178
# 2319 agent: 1.0988 venchmark: 1.1366 acc:  0.5178
# 2320 agent: 0.4286 venchmark: 0.8585 acc:  0.5178
# 2321 agent: 1.2852 venchmark: 0.8517 acc:  0.5178
# 2322 agent: 1.3318 venchmark: 1.3449 acc:  0.5177
# 2323 agent: 1.007 venchmark: 1.1213 acc:  0.5177
# 2324 agent: 1.4718 venchmark: 1.2568 acc:  0.5177
# 2325 agent: 0.6794 venchmark: 0.6948 acc:  0.5177
# 2326 agent: 2.4294 venchmark: 1.1613 acc:  0.5178
# 2327 agent: 2.2477 venchmark: 1.2332 acc:  0.5178
# 2328 agent: 1.0446 venchmark: 1.1614 acc:  0.5178
# 2329 agent: 0.8991 venchmark: 0.8309 acc:  0.5178
# 2330 agent: 0.8564 venchmark: 0.9176 acc:  0.5178
# 2331 agent: 2.3312 venchmark: 1.1824 acc:  0.5178
# 2332 agent: 0.9594 venchmark: 1.1834 acc:  0.5178
# 2333 agent: 1.7612 venchmark: 1.3041 acc:  0.5178
# 2334 agent: 1.855 venchmark: 1.1981 acc:  0.5179
# 2335 agent: 5.9482 venchmark: 1.272 acc:  0.5179
# 2336 agent: 2.5158 venchmark: 1.338 acc:  0.5179
# 2337 agent: 3.611 venchmark: 0.8463 acc:  0.5179
# 2338 agent: 0.4934 venchmark: 1.3751 acc:  0.5179
# 2339 agent: 0.6413 venchmark: 1.1881 acc:  0.5179
# 2340 agent: 0.9816 venchmark: 1.2854 acc:  0.5179
# 2341 agent: 1.7394 venchmark: 1.2746 acc:  0.5179
# 2342 agent: 0.7099 venchmark: 1.0767 acc:  0.5179
# 2343 agent: 0.2388 venchmark: 1.0248 acc:  0.5179
# 2344 agent: 2.3263 venchmark: 1.4991 acc:  0.5179
# 2345 agent: 1.5551 venchmark: 1.0946 acc:  0.5179
# 2346 agent: 1.1204 venchmark: 1.2922 acc:  0.5179
# 2347 agent: 1.348 venchmark: 1.023 acc:  0.5179
# 2348 agent: 0.6577 venchmark: 1.4086 acc:  0.5178
# 2349 agent: 1.0086 venchmark: 1.0285 acc:  0.5178
# 2350 agent: 1.7002 venchmark: 0.9588 acc:  0.5178
# 2351 agent: 0.3176 venchmark: 0.5927 acc:  0.5178
# 2352 agent: 1.5214 venchmark: 1.1198 acc:  0.5178
# 2353 agent: 3.295 venchmark: 1.5203 acc:  0.5178
# 2354 agent: 3.9147 venchmark: 1.498 acc:  0.5179
# 2355 agent: 0.6489 venchmark: 1.4133 acc:  0.5178
# 2356 agent: 1.3785 venchmark: 1.1135 acc:  0.5178
# 2357 agent: 1.5986 venchmark: 1.1706 acc:  0.5178
# 2358 agent: 0.8267 venchmark: 1.4584 acc:  0.5178
# 2359 agent: 1.9126 venchmark: 1.0431 acc:  0.5178
# 2360 agent: 1.1063 venchmark: 1.4761 acc:  0.5179
# 2361 agent: 0.5319 venchmark: 0.6997 acc:  0.5178
# 2362 agent: 0.3293 venchmark: 0.9945 acc:  0.5179
# 2363 agent: 1.4417 venchmark: 1.3855 acc:  0.5178
# 2364 agent: 5.693 venchmark: 1.4393 acc:  0.5178
# 2365 agent: 1.2375 venchmark: 1.1086 acc:  0.5178
# 2366 agent: 1.3725 venchmark: 1.1647 acc:  0.5178
# 2367 agent: 0.5262 venchmark: 1.0374 acc:  0.5178
# 2368 agent: 2.1464 venchmark: 1.5667 acc:  0.5178
# 2369 agent: 1.8441 venchmark: 1.1828 acc:  0.5177
# 2370 agent: 1.8276 venchmark: 0.8558 acc:  0.5177
# 2371 agent: 0.8921 venchmark: 1.1474 acc:  0.5177
# 2372 agent: 0.8406 venchmark: 0.9225 acc:  0.5177
# 2373 agent: 1.1362 venchmark: 1.2909 acc:  0.5177
# 2374 agent: 0.9587 venchmark: 1.0249 acc:  0.5177
# 2375 agent: 0.5102 venchmark: 0.8132 acc:  0.5177
# 2376 agent: 0.5935 venchmark: 0.8122 acc:  0.5177
# 2377 agent: 0.6594 venchmark: 1.0138 acc:  0.5177
# 2378 agent: 0.4945 venchmark: 1.0052 acc:  0.5177
# 2379 agent: 1.5701 venchmark: 1.1709 acc:  0.5177
# 2380 agent: 1.7326 venchmark: 1.0743 acc:  0.5177
# 2381 agent: 2.7376 venchmark: 1.4229 acc:  0.5177
# 2382 agent: 0.7895 venchmark: 0.8815 acc:  0.5177
# 2383 agent: 0.4821 venchmark: 0.8345 acc:  0.5178
# 2384 agent: 0.7501 venchmark: 1.1417 acc:  0.5178
# 2385 agent: 0.9242 venchmark: 1.2038 acc:  0.5178
# 2386 agent: 0.7538 venchmark: 0.9987 acc:  0.5178
# 2387 agent: 1.4799 venchmark: 1.1518 acc:  0.5178
# 2388 agent: 1.5307 venchmark: 0.9442 acc:  0.5178
# 2389 agent: 1.6956 venchmark: 1.4071 acc:  0.5178
# 2390 agent: 0.7536 venchmark: 0.824 acc:  0.5178
# 2391 agent: 1.1486 venchmark: 0.8185 acc:  0.5178
# 2392 agent: 1.2512 venchmark: 0.9426 acc:  0.5178
# 2393 agent: 1.1438 venchmark: 0.7129 acc:  0.5178
# 2394 agent: 0.479 venchmark: 0.8781 acc:  0.5177
# 2395 agent: 0.8029 venchmark: 1.1382 acc:  0.5177
# 2396 agent: 0.6449 venchmark: 0.8782 acc:  0.5177
# 2397 agent: 0.5072 venchmark: 0.984 acc:  0.5178
# 2398 agent: 0.9782 venchmark: 0.8362 acc:  0.5178
# 2399 agent: 0.8516 venchmark: 0.9623 acc:  0.5178
# saved
# average return:  33.529999999999994 %
# AAM loss: -1460.0334990024567 ESM loss: 1972368.4825880527
# 2400 agent: 0.867 venchmark: 1.2187 acc:  0.5178
# 2401 agent: 1.1013 venchmark: 1.1632 acc:  0.5178
# 2402 agent: 1.6814 venchmark: 0.9862 acc:  0.5178
# 2403 agent: 0.8714 venchmark: 1.3859 acc:  0.5178
# 2404 agent: 0.8095 venchmark: 0.8151 acc:  0.5178
# 2405 agent: 0.861 venchmark: 0.8181 acc:  0.5178
# 2406 agent: 1.2606 venchmark: 0.8086 acc:  0.5178
# 2407 agent: 1.0527 venchmark: 1.0957 acc:  0.5178
# 2408 agent: 0.8092 venchmark: 1.0909 acc:  0.5179
# 2409 agent: 0.4054 venchmark: 1.2003 acc:  0.5179
# 2410 agent: 2.2587 venchmark: 1.1236 acc:  0.5179
# 2411 agent: 1.3882 venchmark: 1.1829 acc:  0.5179
# 2412 agent: 2.5772 venchmark: 1.0479 acc:  0.5178
# 2413 agent: 2.6182 venchmark: 1.1375 acc:  0.5179
# 2414 agent: 1.6532 venchmark: 0.9472 acc:  0.5179
# 2415 agent: 1.0893 venchmark: 1.2939 acc:  0.5179
# 2416 agent: 0.9607 venchmark: 1.4212 acc:  0.5179
# 2417 agent: 1.4484 venchmark: 1.4983 acc:  0.5179
# 2418 agent: 0.859 venchmark: 1.3501 acc:  0.5178
# 2419 agent: 1.2413 venchmark: 1.4239 acc:  0.5179
# 2420 agent: 0.7309 venchmark: 0.8545 acc:  0.5179
# 2421 agent: 0.623 venchmark: 1.0686 acc:  0.5179
# 2422 agent: 1.7913 venchmark: 1.2119 acc:  0.5179
# 2423 agent: 1.0355 venchmark: 1.0543 acc:  0.5179
# 2424 agent: 2.1443 venchmark: 1.097 acc:  0.5179
# 2425 agent: 0.7796 venchmark: 0.7517 acc:  0.5179
# 2426 agent: 0.9067 venchmark: 0.9983 acc:  0.5179
# 2427 agent: 0.7788 venchmark: 0.8498 acc:  0.5179
# 2428 agent: 1.9719 venchmark: 1.1851 acc:  0.5179
# 2429 agent: 1.0545 venchmark: 1.2283 acc:  0.5179
# 2430 agent: 0.8888 venchmark: 0.8417 acc:  0.5178
# 2431 agent: 0.5749 venchmark: 0.6526 acc:  0.5179
# 2432 agent: 2.1512 venchmark: 1.5738 acc:  0.5179
# 2433 agent: 1.098 venchmark: 1.107 acc:  0.5179
# 2434 agent: 1.4624 venchmark: 0.9663 acc:  0.5179
# 2435 agent: 1.5834 venchmark: 1.3653 acc:  0.5179
# 2436 agent: 0.2855 venchmark: 0.9903 acc:  0.5179
# 2437 agent: 1.4108 venchmark: 1.448 acc:  0.518
# 2438 agent: 1.2569 venchmark: 1.5163 acc:  0.518
# 2439 agent: 0.5922 venchmark: 0.8799 acc:  0.5179
# 2440 agent: 0.6033 venchmark: 0.7627 acc:  0.5179
# 2441 agent: 1.7589 venchmark: 1.1811 acc:  0.5179
# 2442 agent: 0.9424 venchmark: 0.885 acc:  0.5179
# 2443 agent: 0.8187 venchmark: 1.0244 acc:  0.5179
# 2444 agent: 0.9603 venchmark: 1.4618 acc:  0.5179
# 2445 agent: 0.7769 venchmark: 0.9852 acc:  0.5179
# 2446 agent: 1.6536 venchmark: 0.9731 acc:  0.518
# 2447 agent: 0.9574 venchmark: 0.9461 acc:  0.518
# 2448 agent: 0.7068 venchmark: 1.2658 acc:  0.518
# 2449 agent: 1.1683 venchmark: 1.3459 acc:  0.5179
# 2450 agent: 1.3363 venchmark: 1.4851 acc:  0.5179
# 2451 agent: 1.0822 venchmark: 1.2361 acc:  0.5179
# 2452 agent: 2.637 venchmark: 1.6736 acc:  0.5179
# 2453 agent: 0.566 venchmark: 1.0425 acc:  0.5179
# 2454 agent: 0.6948 venchmark: 0.8203 acc:  0.5179
# 2455 agent: 1.4303 venchmark: 0.9268 acc:  0.5179
# 2456 agent: 0.7908 venchmark: 0.6212 acc:  0.5179
# 2457 agent: 0.9138 venchmark: 1.3474 acc:  0.5179
# 2458 agent: 1.221 venchmark: 1.0499 acc:  0.5179
# 2459 agent: 1.0371 venchmark: 0.8763 acc:  0.518
# 2460 agent: 0.6458 venchmark: 0.899 acc:  0.518
# 2461 agent: 2.1623 venchmark: 0.9228 acc:  0.518
# 2462 agent: 1.1806 venchmark: 0.9737 acc:  0.518
# 2463 agent: 1.5604 venchmark: 0.9919 acc:  0.518
# 2464 agent: 1.0646 venchmark: 0.9597 acc:  0.518
# 2465 agent: 1.5854 venchmark: 1.0991 acc:  0.518
# 2466 agent: 0.5325 venchmark: 0.8286 acc:  0.518
# 2467 agent: 1.3997 venchmark: 1.2177 acc:  0.518
# 2468 agent: 0.6875 venchmark: 0.8562 acc:  0.518
# 2469 agent: 0.2468 venchmark: 0.9996 acc:  0.518
# 2470 agent: 0.6768 venchmark: 1.0323 acc:  0.518
# 2471 agent: 0.9331 venchmark: 0.9277 acc:  0.518
# 2472 agent: 1.8137 venchmark: 0.7801 acc:  0.518
# 2473 agent: 0.944 venchmark: 1.3578 acc:  0.518
# 2474 agent: 3.6043 venchmark: 1.3275 acc:  0.518
# 2475 agent: 1.2272 venchmark: 1.3466 acc:  0.518
# 2476 agent: 0.5246 venchmark: 0.8859 acc:  0.518
# 2477 agent: 0.704 venchmark: 0.9391 acc:  0.5181
# 2478 agent: 1.4303 venchmark: 1.0723 acc:  0.5181
# 2479 agent: 1.275 venchmark: 0.9392 acc:  0.5181
# 2480 agent: 1.9131 venchmark: 1.803 acc:  0.5181
# 2481 agent: 1.388 venchmark: 1.513 acc:  0.5181
# 2482 agent: 0.6771 venchmark: 0.7657 acc:  0.5181
# 2483 agent: 0.8136 venchmark: 0.9499 acc:  0.5181
# 2484 agent: 1.1056 venchmark: 0.8667 acc:  0.5181
# 2485 agent: 1.0385 venchmark: 1.3948 acc:  0.5181
# 2486 agent: 1.0109 venchmark: 0.8468 acc:  0.5181
# 2487 agent: 1.4116 venchmark: 1.1929 acc:  0.5181
# 2488 agent: 0.4974 venchmark: 0.9277 acc:  0.5181
# 2489 agent: 0.9343 venchmark: 0.9198 acc:  0.5181
# 2490 agent: 2.7573 venchmark: 1.2479 acc:  0.5181
# 2491 agent: 0.4705 venchmark: 0.7827 acc:  0.5181
# 2492 agent: 1.3903 venchmark: 1.2503 acc:  0.5181
# 2493 agent: 1.4227 venchmark: 0.8609 acc:  0.5182
# 2494 agent: 0.8221 venchmark: 1.3761 acc:  0.5182
# 2495 agent: 0.9476 venchmark: 0.8187 acc:  0.5182
# 2496 agent: 0.8945 venchmark: 1.0311 acc:  0.5182
# 2497 agent: 1.345 venchmark: 1.1211 acc:  0.5182
# 2498 agent: 1.0574 venchmark: 1.1457 acc:  0.5182
# 2499 agent: 0.4865 venchmark: 0.9849 acc:  0.5182
# saved
# average return:  17.569999999999997 %
# AAM loss: -1024.1508622169495 ESM loss: 1972270.6134489179
# 2500 agent: 1.4774 venchmark: 1.1686 acc:  0.5182
# 2501 agent: 0.7772 venchmark: 1.1411 acc:  0.5182
# 2502 agent: 0.6765 venchmark: 1.461 acc:  0.5182
# 2503 agent: 4.7168 venchmark: 1.2574 acc:  0.5182
# 2504 agent: 1.4315 venchmark: 1.1209 acc:  0.5181
# 2505 agent: 1.2493 venchmark: 0.8747 acc:  0.5181
# 2506 agent: 1.1609 venchmark: 1.3151 acc:  0.5181
# 2507 agent: 1.1798 venchmark: 1.3803 acc:  0.5181
# 2508 agent: 0.7805 venchmark: 1.299 acc:  0.5181
# 2509 agent: 0.6319 venchmark: 1.1988 acc:  0.5181
# 2510 agent: 2.1338 venchmark: 1.2801 acc:  0.5181
# 2511 agent: 0.7668 venchmark: 1.0084 acc:  0.518
# 2512 agent: 0.978 venchmark: 0.8057 acc:  0.518
# 2513 agent: 3.7942 venchmark: 1.1935 acc:  0.518
# 2514 agent: 0.7201 venchmark: 0.8594 acc:  0.518
# 2515 agent: 0.7275 venchmark: 1.0744 acc:  0.5181
# 2516 agent: 1.078 venchmark: 1.3199 acc:  0.5181
# 2517 agent: 1.3584 venchmark: 0.9568 acc:  0.5181
# 2518 agent: 2.3061 venchmark: 1.1074 acc:  0.5181
# 2519 agent: 0.3854 venchmark: 1.1208 acc:  0.5181
# 2520 agent: 0.6492 venchmark: 1.1172 acc:  0.5181
# 2521 agent: 0.8112 venchmark: 1.2499 acc:  0.5181
# 2522 agent: 0.584 venchmark: 1.1481 acc:  0.5181
# 2523 agent: 1.3778 venchmark: 1.0432 acc:  0.518
# 2524 agent: 0.5136 venchmark: 0.8077 acc:  0.518
# 2525 agent: 3.1587 venchmark: 0.7088 acc:  0.5181
# 2526 agent: 1.1764 venchmark: 0.9446 acc:  0.5181
# 2527 agent: 0.3519 venchmark: 1.173 acc:  0.5181
# 2528 agent: 0.7763 venchmark: 0.7929 acc:  0.5181
# 2529 agent: 1.4281 venchmark: 0.8688 acc:  0.5181
# 2530 agent: 1.3746 venchmark: 0.7941 acc:  0.5181
# 2531 agent: 1.8902 venchmark: 0.8161 acc:  0.5182
# 2532 agent: 0.7399 venchmark: 1.2125 acc:  0.5181
# 2533 agent: 1.3754 venchmark: 0.9192 acc:  0.5182
# 2534 agent: 1.8527 venchmark: 1.22 acc:  0.5182
# 2535 agent: 1.5388 venchmark: 0.7961 acc:  0.5182
# 2536 agent: 0.6205 venchmark: 1.0462 acc:  0.5182
# 2537 agent: 0.8956 venchmark: 0.8941 acc:  0.5182
# 2538 agent: 0.8052 venchmark: 0.9196 acc:  0.5182
# 2539 agent: 1.081 venchmark: 1.1002 acc:  0.5182
# 2540 agent: 1.073 venchmark: 0.739 acc:  0.5182
# 2541 agent: 1.915 venchmark: 1.487 acc:  0.5182
# 2542 agent: 1.2801 venchmark: 0.9397 acc:  0.5182
# 2543 agent: 0.8307 venchmark: 0.9871 acc:  0.5182
# 2544 agent: 2.3275 venchmark: 1.0303 acc:  0.5183
# 2545 agent: 1.7211 venchmark: 1.8838 acc:  0.5183
# 2546 agent: 3.1963 venchmark: 1.1911 acc:  0.5183
# 2547 agent: 1.1482 venchmark: 1.2302 acc:  0.5183
# 2548 agent: 0.9886 venchmark: 1.3399 acc:  0.5182
# 2549 agent: 4.1693 venchmark: 1.4185 acc:  0.5182
# 2550 agent: 1.534 venchmark: 1.3883 acc:  0.5182
# 2551 agent: 1.0819 venchmark: 1.1708 acc:  0.5183
# 2552 agent: 0.9425 venchmark: 0.8591 acc:  0.5182
# 2553 agent: 2.1841 venchmark: 1.0033 acc:  0.5182
# 2554 agent: 2.9443 venchmark: 1.6716 acc:  0.5182
# 2555 agent: 1.2366 venchmark: 0.9279 acc:  0.5182
# 2556 agent: 1.186 venchmark: 0.8886 acc:  0.5182
# 2557 agent: 0.8283 venchmark: 0.8995 acc:  0.5182
# 2558 agent: 0.6462 venchmark: 0.9443 acc:  0.5182
# 2559 agent: 1.9436 venchmark: 1.1964 acc:  0.5182
# 2560 agent: 1.4439 venchmark: 1.9032 acc:  0.5182
# 2561 agent: 1.0218 venchmark: 1.1009 acc:  0.5182
# 2562 agent: 0.8588 venchmark: 1.0776 acc:  0.5182
# 2563 agent: 0.8655 venchmark: 1.2824 acc:  0.5182
# 2564 agent: 1.9786 venchmark: 1.4685 acc:  0.5182
# 2565 agent: 1.3509 venchmark: 1.076 acc:  0.5182
# 2566 agent: 0.803 venchmark: 0.7985 acc:  0.5182
# 2567 agent: 0.3879 venchmark: 1.186 acc:  0.5182
# 2568 agent: 1.0296 venchmark: 1.368 acc:  0.5182
# 2569 agent: 0.694 venchmark: 1.5664 acc:  0.5182
# 2570 agent: 3.8273 venchmark: 0.9707 acc:  0.5182
# 2571 agent: 0.9494 venchmark: 1.1604 acc:  0.5182
# 2572 agent: 0.6846 venchmark: 0.6115 acc:  0.5182
# 2573 agent: 1.3357 venchmark: 1.3245 acc:  0.5182
# 2574 agent: 1.37 venchmark: 0.7342 acc:  0.5182
# 2575 agent: 1.2315 venchmark: 1.1121 acc:  0.5182
# 2576 agent: 1.0267 venchmark: 0.9298 acc:  0.5182
# 2577 agent: 1.0372 venchmark: 1.4487 acc:  0.5183
# 2578 agent: 0.9756 venchmark: 0.8034 acc:  0.5183
# 2579 agent: 2.3358 venchmark: 1.1179 acc:  0.5183
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-07c95274545f> in <module>
#      25             selected_s = MM_scaler(selected_s)
#      26             w = allocator.predict(selected_s)
# ---> 27             s_prime,r,done,v_prime,growth = env.action(w)
#      28             s_prime=MM_scaler(s_prime)
#      29             allocator_memory.append([selected_s,r])
#
# ~/workspace/kospi_portfolio_reinforcement_learningv4/environment.py in action(self, weight)
#     108
#     109         for i in range(len(self.individual_return)):
# --> 110             if self.individual_return[i]>0 and self.value_array[i]>0:
#     111                 self.acc[0,0]+=1
#     112             if self.individual_return[i]==0 and self.value_array[i]>0:
#
# KeyboardInterrupt:
